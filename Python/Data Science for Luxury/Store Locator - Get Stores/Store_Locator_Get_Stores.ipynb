# %%
import pandas as pd
import numpy as np
import time
from lxml import html
import os
import re
import yaml
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from sqlalchemy import create_engine, text
import pymysql

# %%
def launch_selenium(lang='fr'):
    options = Options()

    if lang == 'fr':
        options.add_argument("--lang=fr-FR")

    if lang == 'en':
        options.add_argument("--lang=en")
        
    prefs = {
        #"prefs": {'intl.accept_languages': 'en,en_US'},
        "translate":{"enabled":"true"}
    }
    options.add_experimental_option("prefs", prefs)

    options.add_argument('--ignore-certificate-errors')
    #options.add_argument('--incognito') #can not use extensions
    #options.add_argument('--headless')
    #options.add_argument("--window-size=1000,800")
    #options.add_argument('--no-sandbox')
    options.add_argument("--start-maximized")
    #options.add_argument("--disable-notifications")
    #options.add_argument("--disable-popup-blocking")
    options.add_extension('extensions/J2TEAM_Cookies.crx')
    options.add_extension('extensions/setupvpn.crx')
    chrome_path = 'driver/chromedriver_89.exe'
    driver = webdriver.Chrome(chrome_path, options=options)
    
    #close windows
    while len(driver.window_handles)>1:
        driver.switch_to.window(driver.window_handles[len(driver.window_handles)-1])
        time.sleep(0.5)
        driver.close()
        time.sleep(0.5)
    driver.switch_to.window(driver.window_handles[len(driver.window_handles)-1])
    
    return driver

# %%
def get_page(driver):
    #get content of the page
    content = driver.page_source
    page = html.fromstring(content) 
    
    return page


def get_items(driver, xpath):
    #get content of the page
    page = get_page(driver)
    
    #xpath items
    items = page.xpath(xpath)
    
    return items

def get_value(item, config, elem):
    try:
        xpath_elem = config[elem]
        
        v = item.xpath(xpath_elem)
        if len(v)>0:
            v = v[0]
        else:
            return None

        #clean_value
        #if '@href' in xpath_elem:
            #v = format_url('amazon.com', v)
        #elif 'text()' in xpath_elem:
        if 'text()' in xpath_elem:
            v = clean_text(v)

        return v      
    except:
        return None

def format_url(domain, url):
    try:
        if 'http' not in url:
            if url[0] == '/':
                return 'https://www.' + domain + url
    except:
        return np.nan
    
def clean_text(txt):
    try:
        txt = txt.strip()
        txt = re.sub('\n', '', txt)
        return txt
    except:
        return np.nan

# %%
def extract_partner(x, brand):
    dict_partner = {
        'Audemars Piguet': ['ap house', 'audemars piguet'],
        'Ferrari': ['ferrari'],
        'Breguet': ['breguet boutique', 'breguet store', 'boutique breguet'],
        'Rolex': ['rolex boutique', 'boutique rolex', 'rolex shop'],
        'Tag Heuer': ['tag heuer'],
        'Zenith': ['zenith'],
        'Omega': ['omega'],
        'Tudor': ['boutique'],
        'Chopard': ['boutique'],
        'Bvlgari': ['boutique']
    }
    official_kw_list = dict_partner[brand]
    try:
        x = str(x).lower()
        x = re.sub('\s{2,}', '', x)
        for kw in official_kw_list:
            if kw in x:
                return 0
        return 1
    except:
        return 1

# %% [markdown]
# # COLLECT STORES

# %%
driver = launch_selenium('en')

# %%
with open('./config/config_store_locator.yaml', 'r', encoding='utf-8') as file:
    config_all = yaml.safe_load(file)

# %% [markdown]
# # CHANEL

# %%
config = config_all['CHANEL']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Filter Chanel Stores on Fashion only
# - Dezoom '10z' (Check url on map) is the maximal dezoom to find stores
# - Enter each city based on the list of cities already scraped in database

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    address = get_value(item, config, 'address')
    store_name = get_value(item, config, 'store_name')
    city = get_value(item, config, 'city')
    rows_list.append({
        'store_name': store_name,
        'city': city,
        'address': address,
        'brand': 'Chanel',
        'is_partner': '0'
    })
    
items_r = get_items(driver, config["items_r"])
print('retailers:', len(items_r))

for item in items_r:
    address = get_value(item, config, 'address')
    store_name = get_value(item, config, 'store_name_r')
    city = get_value(item, config, 'city')
    rows_list.append({
        'store_name': store_name,
        'city': city,
        'address': address,
        'brand': 'Chanel',
        'is_partner': '1'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 0
# retailers: 2
# total stores: 298

# %%
df.head()
# Out:
#                  store_name                                   city  \
# 0   CHANEL WESTFIELD SYDNEY          2000, Sydney, New South Wales
# 1  CHANEL DAVID JONES SHOES          2000, Sydney, New South Wales
# 2             CHANEL SYDNEY          2000, Sydney, New South Wales
# 3     CHANEL BONDI JUNCTION  2022, Bondi Junction, New South Wales
# 8          CHANEL CHADSTONE              3148, Chadstone, Victoria
#
#                                              address   brand is_partner
# 0  Shop 4026/28, Level 4, Cnr Pitt St Mall and Ma...  Chanel          0
# 1                          86-108 Castlereagh Street  Chanel          0
# 2                              70 Castlereagh Street  Chanel          0
# 3                                  500 Oxford Street  Chanel          0
# 8                                1341 Dandenong Road  Chanel          0

# %%
brand = 'CHANEL'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/CHANEL_092021.xlsx

# %% [markdown]
# # DIOR

# %%
config = config_all['DIOR']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Filter Dior Stores on Womens Fashion only (Men Fashion should be included)
# - Navigate with dezoom on continents and countries and use "Search in this area" button
# - Search Manually Hawai & Guam / Northern Mariana Islands

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    address = get_value(item, config, 'address')
    store_name = get_value(item, config, 'store_name')
    city = get_value(item, config, 'city')
    city2 = get_value(item, config, 'city2')
    if city2 is None:
        city = city
    else:
        city = city2
    rows_list.append({
        'store_name': store_name,
        'city': city,
        'address': address,
        'brand': 'Dior',
        'is_partner': '0'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 5
# total stores: 258

# %%
df.head()
# Out:
#                         store_name         city                  address  \
# 0      dior - paris la samaritaine  75001 paris      9 rue de la monnaie
# 1       dior - paris le bon marche  75007 paris        5 rue de babylone
# 2        dior - paris saint-honoré  75001 paris    261, rue saint-honoré
# 3  dior - paris galeries lafayette  75009 paris  40, boulevard haussmann
# 4              dior - paris royale  75008 paris            25 rue royale
#
#   brand is_partner
# 0  Dior          0
# 1  Dior          0
# 2  Dior          0
# 3  Dior          0
# 4  Dior          0

# %%
brand = 'DIOR'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/DIOR_092021.xlsx

# %% [markdown]
# # HERMES

# %%
config = config_all['HERMES']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - On Map View, dezoom max and click on "Find" without any entree to see all stores
# - Then go on list view and load all data with "See more" button

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    store_name = get_value(item, config, 'store_name')
    address_city = get_value(item, config, 'address_city')
        
    rows_list.append({
        'country': country,
        'store_name': store_name,
        'address_city': address_city,
        'brand': 'Hermès',
        'is_partner': '0'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 308

# %%
df.head()
# Out:
#   country              store_name  \
# 0  France  Hermès Aix en Provence
# 1  France         Hermès Biarritz
# 2  France         Hermès Bordeaux
# 3  France           Hermès Cannes
# 4  France       Hermès Courchevel
#
#                                         address_city   brand is_partner
# 0    26, place de Verdun,   Aix-en-Provence,  13100,  Hermès          0
# 1        19, Avenue Edouard VII,   Biarritz,  64200,  Hermès          0
# 2            2, Place Gambetta,   Bordeaux,  33000 ,  Hermès          0
# 3   52 boulevard de la Croisette,   Cannes,  06400 ,  Hermès          0
# 4  Le Coeur de Courchevel , 1850 Rue du Rocher,  ...  Hermès          0

# %%
brand = 'HERMES'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/HERMES_092021.xlsx

# %% [markdown]
# # LOUIS VUITTON

# %% [markdown]
# - Use webscraper.io
# - To load all data you need to dezoom maximally on the map view
# - Put 20000 on request in order to have 20 sec to update stores on map

# %%
#webscraper.io sitemap:
"""
{"_id":"LOUIS_VUITTON_102020","startUrl":["https://eu.louisvuitton.com/eng-e1/stores"],"selectors":[{"id":"elem","type":"SelectorElement","parentSelectors":["_root"],"selector":"li.storeItem","multiple":true,"delay":0},{"id":"store_name","type":"SelectorText","parentSelectors":["elem"],"selector":"h3","multiple":false,"regex":"","delay":0},{"id":"store_address","type":"SelectorText","parentSelectors":["elem"],"selector":"p","multiple":false,"regex":"","delay":0}]}
"""
# Out:
# '\n{"_id":"LOUIS_VUITTON_102020","startUrl":["https://eu.louisvuitton.com/eng-e1/stores"],"selectors":[{"id":"elem","type":"SelectorElement","parentSelectors":["_root"],"selector":"li.storeItem","multiple":true,"delay":0},{"id":"store_name","type":"SelectorText","parentSelectors":["elem"],"selector":"h3","multiple":false,"regex":"","delay":0},{"id":"store_address","type":"SelectorText","parentSelectors":["elem"],"selector":"p","multiple":false,"regex":"","delay":0}]}\n'

# %% [markdown]
# # AUDEMARS PIGUET

# %% [markdown]
# - Filter on "Where to buy" before scraping

# %%
config = config_all['AUDEMARS PIGUET']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Dezoom on map to get all stores points (take service centers also)
# - "Show list results" gives you the number of stores you need to collect

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    store_name = get_value(item, config, 'store_name')
    address_city = get_value(item, config, 'address_city')
    status = get_value(item, config, 'status')
        
    rows_list.append({
        'store_name': store_name,
        'address_city': address_city,
        'status': status,
        'brand': 'Audemars Piguet'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 20
# total stores: 151

# %%
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Audemars Piguet'))

# %%
df
# Out:
#                                            store_name  \
# 0                                  AP House Barcelona
# 1                                     AP House Madrid
# 2                     Audemars Piguet Boutique Monaco
# 3            Audemars Piguet Boutique Geneva Fusterie
# 4    Audemars Piguet Boutique Geneva Montres Prestige
# ..                                                ...
# 777                            AP House St Barthélemy
# 783                                     Joyeria Bauer
# 796                                           Chronos
# 797                                      Eve Joyerias
# 800                                             Mosso
#
#                                           address_city status  \
# 0                Passeig de Gracia 37, 08006 Barcelona   None
# 1                   Calle de Serrano, 66, 28001 Madrid   None
# 2                 2 avenue des Spélugues, 98000 Monaco   None
# 3                 Place de la Fusterie 12, 1204 Geneva   None
# 4    Quai du mont-blanc 19, Fairmont Grand Hôtel, 1...   None
# ..                                                 ...    ...
# 777     Rue de la République, Gustavia, 97133 Gustavia   None
# 783                       Carrera 15 n° 93-60,  Bogota   None
# 796                          Chronos, 11300 Montevideo   None
# 797              Puerto Madero Este, 1107 Buenos Aires   None
# 800        Avenida Luis Pasteur 5846, 7640648 Santiago   None
#
#                brand  is_partner
# 0    Audemars Piguet           0
# 1    Audemars Piguet           0
# 2    Audemars Piguet           0
# 3    Audemars Piguet           0
# 4    Audemars Piguet           0
# ..               ...         ...
# 777  Audemars Piguet           0
# 783  Audemars Piguet           1
# 796  Audemars Piguet           1
# 797  Audemars Piguet           1
# 800  Audemars Piguet           1
#
# [151 rows x 5 columns]

# %%
brand = 'AUDEMARS_PIGUET'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/AUDEMARS_PIGUET_092021.xlsx

# %% [markdown]
# # LAMBORGHINI

# %%
config = config_all['LAMBORGHINI']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Dezoom on map and click on "Clear Filters" to update all stores

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    address = get_value(item, config, 'address')
    store_name = get_value(item, config, 'store_name')
    rows_list.append({
        'address': address,
        'store_name': store_name,
        'brand': 'Lamborghini',
        'is_partner': '0'
    })
        
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 23
# total stores: 154

# %%
df
# Out:
#                                                address  \
# 0    ul. Polczynska 120 B 00-347 Warszawa PL 00-347...
# 1    Via de Las Dos Castillas 9 28224 Pozuelo De Al...
# 2    Rua São Francisco 582, Alcabideche 2645-019 Al...
# 3    Pr. Mohammed Bin Abdul Aziz Street P.O. Box :3...
# 4    Al-Tilal Complex, Pepsi Road 80, Shuwaikh Indu...
# ..                                                 ...
# 701  4-34-4 HARADA HIGASHI-KU FUKUOKA-SHI 812 0063 ...
# 702  44-1, Shinden, Nanakita, Izumi-ku, Sendai-shi,...
# 734  382 Swan St. Richmond 'Vic 3141 Richmond VIC A...
# 735  622(Samsung-dong) Yeongdong-daero, Gangnam-gu ...
# 755  269-275 Glen Osmond Road Frewville SA null Ade...
#
#                                       store_name        brand is_partner
# 0                  Exclusive Cars Vertriebs Gmbh  Lamborghini          0
# 1    Jemercar Tecnicos Del Automovil Services SL  Lamborghini          0
# 2                                        Siva SA  Lamborghini          0
# 3     Saudi Arabian Marketing & Agencies Co. Ltd  Lamborghini          0
# 4               Fouad Alghanim & Sons Automotive  Lamborghini          0
# ..                                           ...          ...        ...
# 701                                  RPM Co. Ltd  Lamborghini          0
# 702                  Tajima Motor Corporation Co  Lamborghini          0
# 734                      Zagame Automotive Group  Lamborghini          0
# 735                         Sqda Motors Co., Ltd  Lamborghini          0
# 755              Zagame Automotive Group Pty Ltd  Lamborghini          0
#
# [154 rows x 4 columns]

# %%
brand = 'LAMBORGHINI'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/LAMBORGHINI_092021.xlsx

# %% [markdown]
# # FERRARI

# %%
config = config_all['FERRARI']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Click on "SALE" to get stores

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    
    res = item.xpath(config['store_name_city'])
    for store_name_city in res:
        store_name = store_name_city.split(',')[0]
        city = store_name_city.split(', ')[1]
        
        rows_list.append({
            'country': country,
            'store_name': store_name,
            'city': city,
            'brand': 'Ferrari'
        })
        
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 262

# %%
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Ferrari'))

# %%
df.head()
# Out:
#    country             store_name       city    brand  is_partner
# 0   U.A.E.  Al Tayer Motors L.L.C      Dubai  Ferrari           1
# 1   U.A.E.  Premier Motors L.L.C.  Abu Dhabi  Ferrari           1
# 2  Bahrain            Euro Motors      Sitra  Ferrari           1
# 3    India            Select Cars  New Delhi  Ferrari           1
# 4    India          Navnit Motors     Mumbai  Ferrari           1

# %%
brand = 'FERRARI'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/FERRARI_092021.xlsx

# %% [markdown]
# # PATEK PHILIPPE

# %%
config = config_all['PATEK PHILIPPE']

# %%
rows_list = []

# %% [markdown]
# - Change urls to get both boutiques and retailers

# %%
#BOUTIQUES
driver.get(config['start_url'][0])

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    store_name = get_value(item, config, 'store_name')
    address = ', '.join(item.xpath(config['address']))
    city = get_value(item, config, 'city')
        
    rows_list.append({
        'country': country,
        'store_name': store_name,
        'city': city,
        'address': address,
        'brand': 'Patek Philippe',
        'is_partner': '0'
    })
    
print(len(rows_list), 'boutiques collected')
# Out:
# 12 boutiques collected

# %%
#RETAILERS
driver.get(config['start_url'][1])

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    store_name = get_value(item, config, 'store_name')
    address = ', '.join(item.xpath(config['address']))
    city = get_value(item, config, 'city')
        
    rows_list.append({
        'country': country,
        'store_name': store_name,
        'city': city,
        'address': address,
        'brand': 'Patek Philippe',
        'is_partner': '1'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 389

# %%
df.head()
# Out:
#                country                                store_name         city  \
# 0              Germany              Deutsche Patek Philippe GmbH      München
# 1            Singapore          Geneva Master Time Marketing LLP    Singapore
# 2             Thailand  Geneva Master Time Representative Office      Bangkok
# 3               Mexico                  Grupo Mondi S.A. de C.V.  Mexico D.F.
# 4  Hong Kong SAR China                          Libertas Limited      Kowloon
#
#                                              address           brand  \
# 0                                   Brienner Str. 12  Patek Philippe
# 1            501, Orchard Road, 16-01 Wheelock Place  Patek Philippe
# 2  Unit 5B-3, 5th Floor Gaysorn, 999 Ploenchit Ro...  Patek Philippe
# 3  Av. Popocatépetl 204 - Col. General Anaya, Del...  Patek Philippe
# 4  15/F., The Peninsula Office Tower, 18 Middle R...  Patek Philippe
#
#   is_partner
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
brand = 'PATEK_PHILIPPE'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/PATEK_PHILIPPE_092021.xlsx

# %% [markdown]
# # BREGUET

# %%
config = config_all['BREGUET']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Click on retailers
# - Click on "Load more results" until you reach the end

# %%
items = get_items(driver, config["items"])

for item in items:
    store_name = get_value(item, config, 'store_name')
    address = get_value(item, config, 'address')
    city = get_value(item, config, 'city')
        
    rows_list.append({
        'store_name': store_name,
        'address': address,
        'city': city,
        'brand': 'Breguet'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 389

# %%
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Breguet'))

# %%
df
# Out:
#                      store_name  \
# 0         Suïssa at The Embassy
# 1    BOUTIQUE DOS RELÓGIOS PLUS
# 2                   CHRONOGRAPH
# 3           Monards 101 Collins
# 4          Monards Crown Casino
# ..                          ...
# 385              ZADOK JEWELERS
# 386                     Chronos
# 387           «Geneva» boutique
# 389    SWISS MASTER TIME CO LTD
# 390    SWISS MASTER TIME CO LTD
#
#                                                address  \
# 0                              Avinguda Meritxell, 31.
# 1    Edifício ESCOM, secundo piso35-37 Loja I Rua M...
# 2                                   5, Northern Avenue
# 3                                   101 Collins Street
# 4                           Shop 15, 8 Whiteman Street
# ..                                                 ...
# 385                            1749 Post Oak Boulevard
# 386                                   26 de Marzo 3548
# 387  Mirso Ulugbek district\tMustaqillik Shoh Str, ...
# 389                    56 Ly Thai ToHoan Kiem District
# 390      Continental Hotel\t132 Dong Khoi, District 1,
#
#                                city    brand  is_partner
# 0            AD500 Andorra la Vella  Breguet           1
# 1                            Luanda  Breguet           1
# 2                      0001 Yerevan  Breguet           1
# 3                VIC 3000 Melbourne  Breguet           1
# 4    VIC 3006 Southbank,  Melbourne  Breguet           1
# ..                              ...      ...         ...
# 385                TX 77056 Houston  Breguet           1
# 386               11300  Montevideo  Breguet           1
# 387                 100000 Tashkent  Breguet           1
# 389                           Hanoi  Breguet           1
# 390                   HoChiMinhCity  Breguet           1
#
# [389 rows x 5 columns]

# %%
brand = 'BREGUET'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/BREGUET_092021.xlsx

# %% [markdown]
# # VACHERON CONSTANTIN

# %%
config = config_all['VACHERON CONSTANTIN']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    url = get_value(item, config, 'url')
    new_url = 'https://stores.vacheron-constantin.com/' + url
    
    driver.get(new_url)
    time.sleep(2)
    page = get_page(driver)
    
    items_lvl2 = get_items(driver, config["items"])
    if len(items_lvl2) == 0:
        multis = get_items(driver, config["multi"])
        if len(multis) == 0:
            #final_page
            #collect
            city = get_value(page, config, 'city')
            address = get_value(page, config, 'address')
            is_partner = get_value(page, config, 'is_partner')
            store_name = get_value(page, config, 'store_name')
            dict1 = {'city': city,
                    'address': address,
                    'store_name': store_name,
                    'brand': 'Vacheron Constantin',
                    'country': country,
                    'is_partner': is_partner
                    }
            rows_list.append(dict1)     
        else:
            for multi in multis:
                final_url = get_value(multi, config, 'urld')
                final_url = re.sub('\.\./', '', final_url)
                driver.get('https://stores.vacheron-constantin.com/' + final_url)
                page = get_page(driver)
                #final_page
                #collect
                city = get_value(page, config, 'city')
                address = get_value(page, config, 'address')
                is_partner = get_value(page, config, 'is_partner')
                store_name = get_value(page, config, 'store_name')
                dict1 = {'city': city,
                        'address': address,
                        'store_name': store_name,
                        'brand': 'Vacheron Constantin',
                        'country': country,
                        'is_partner': is_partner
                        }
                rows_list.append(dict1)     
    else:
        for item_lvl2 in items_lvl2:
            url = get_value(item_lvl2, config, 'url')
            new_url = 'https://stores.vacheron-constantin.com/' + url
            driver.get(new_url)
            time.sleep(2)
            page = get_page(driver)
            
            items_lvl3 = get_items(driver, config["items"])
            if len(items_lvl3) == 0:
                multis = get_items(driver, config["multi"])
                if len(multis) == 0:
                    #final_page
                    #collect
                    city = get_value(page, config, 'city')
                    address = get_value(page, config, 'address')
                    is_partner = get_value(page, config, 'is_partner')
                    store_name = get_value(page, config, 'store_name')
                    dict1 = {'city': city,
                            'address': address,
                            'store_name': store_name,
                            'brand': 'Vacheron Constantin',
                            'country': country,
                            'is_partner': is_partner
                            }
                    rows_list.append(dict1)     
                else:
                    for multi in multis:
                        final_url = get_value(multi, config, 'urld')
                        final_url = re.sub('\.\./', '', final_url)
                        driver.get('https://stores.vacheron-constantin.com/' + final_url)
                        page = get_page(driver)
                        #final_page
                        #collect
                        city = get_value(page, config, 'city')
                        address = get_value(page, config, 'address')
                        is_partner = get_value(page, config, 'is_partner')
                        store_name = get_value(page, config, 'store_name')
                        dict1 = {'city': city,
                                'address': address,
                                'store_name': store_name,
                                'brand': 'Vacheron Constantin',
                                'country': country,
                                'is_partner': is_partner
                                }
                        rows_list.append(dict1)     
            else:
                for item_lvl3 in items_lvl3:
                    url = get_value(item_lvl3, config, 'url')
                    new_url = 'https://stores.vacheron-constantin.com/' + url
                    driver.get(new_url)
                    time.sleep(2)
                    page = get_page(driver)

                    items_lvl4 = get_items(driver, config["items"])
                    if len(items_lvl4) == 0:
                        multis = get_items(driver, config["multi"])
                        if len(multis) == 0:
                            #final_page
                            #collect
                            city = get_value(page, config, 'city')
                            address = get_value(page, config, 'address')
                            is_partner = get_value(page, config, 'is_partner')
                            store_name = get_value(page, config, 'store_name')
                            dict1 = {'city': city,
                                    'address': address,
                                    'store_name': store_name,
                                    'brand': 'Vacheron Constantin',
                                    'country': country,
                                    'is_partner': is_partner
                                    }
                            rows_list.append(dict1)     
                        else:
                            for multi in multis:
                                final_url = get_value(multi, config, 'urld')
                                final_url = re.sub('\.\./', '', final_url)
                                driver.get('https://stores.vacheron-constantin.com/' + final_url)
                                page = get_page(driver)
                                #final_page
                                #collect
                                city = get_value(page, config, 'city')
                                address = get_value(page, config, 'address')
                                is_partner = get_value(page, config, 'is_partner')
                                store_name = get_value(page, config, 'store_name')
                                dict1 = {'city': city,
                                        'address': address,
                                        'store_name': store_name,
                                        'brand': 'Vacheron Constantin',
                                        'country': country,
                                        'is_partner': is_partner
                                        }
                                rows_list.append(dict1)

df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)

df = df[df['is_partner']!='Vacheron Constantin Service Center']
df.replace("Vacheron Constantin Authorized Retailer", '1', inplace=True)
df.replace('Vacheron Constantin Boutique', '0', inplace=True)
df.replace(np.nan, '0', inplace=True)

print('total stores:', len(df))
# Out:
# total stores: 313

# %%
df.head()
# Out:
#            city                                   address  \
# 0    Casablanca  3, Angle Boulevard Abdelkrim El Khattabi
# 1  Johannesburg                    Shop HL15,Melrose Arch
# 2  Johannesburg         Shop U77 Upper floor,Sandton City
# 3  Johannesburg                          Ballyclare Drive
# 4     Melbourne                         88 Collins Street
#
#                    store_name                brand       country is_partner
# 0       Quantième - Quantième  Vacheron Constantin       Morocco          1
# 1         Elegance - Elegance  Vacheron Constantin  South Africa          1
# 2         Elegance - Elegance  Vacheron Constantin  South Africa          1
# 3                Johannesburg  Vacheron Constantin  South Africa          0
# 4  Melbourne - Collins Street  Vacheron Constantin     Australia          0

# %%
brand = 'VACHERON_CONSTANTIN'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/VACHERON_CONSTANTIN_092021.xlsx

# %% [markdown]
# # CARTIER

# %% [markdown]
# BOUTIQUES

# %%
config = config_all['CARTIER_BOUTIQUES']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
items = get_items(driver, config["items"])

for item in items:
    country = get_value(item, config, 'country')
    url = get_value(item, config, 'url')
    new_url = 'https://stores.cartier.com/' + url
    
    driver.get(new_url)
    time.sleep(2)
    page = get_page(driver)
    
    items_lvl2 = get_items(driver, config["items"])
    if len(items_lvl2) == 0:
        multis = get_items(driver, config["multi"])
        if len(multis) == 0:
            #final_page
            #collect
            city = get_value(page, config, 'city')
            address = get_value(page, config, 'address')
            store_name = get_value(page, config, 'store_name')
            store_name2 = get_value(page, config, 'store_name2')
            dict1 = {'city': city,
                    'address': address,
                    'store_name': store_name+' '+store_name2,
                    'brand': 'Cartier',
                    'country': country,
                    'is_partner': 0
                    }
            rows_list.append(dict1)     
        else:
            for multi in multis:
                final_url = get_value(multi, config, 'urld')
                final_url = re.sub('\.\./', '', final_url)
                driver.get('https://stores.cartier.com/' + final_url)
                page = get_page(driver)
                #final_page
                #collect
                city = get_value(page, config, 'city')
                address = get_value(page, config, 'address')
                store_name = get_value(page, config, 'store_name')
                store_name2 = get_value(page, config, 'store_name2')
                dict1 = {'city': city,
                        'address': address,
                        'store_name': store_name+' '+store_name2,
                        'brand': 'Cartier',
                        'country': country,
                        'is_partner': 0
                        }
                rows_list.append(dict1)     
    else:
        for item_lvl2 in items_lvl2:
            url = get_value(item_lvl2, config, 'url')
            new_url = 'https://stores.cartier.com/' + url
            driver.get(new_url)
            time.sleep(2)
            page = get_page(driver)
            
            items_lvl3 = get_items(driver, config["items"])
            if len(items_lvl3) == 0:
                multis = get_items(driver, config["multi"])
                if len(multis) == 0:
                    #final_page
                    #collect
                    city = get_value(page, config, 'city')
                    address = get_value(page, config, 'address')
                    store_name = get_value(page, config, 'store_name')
                    store_name2 = get_value(page, config, 'store_name2')
                    dict1 = {'city': city,
                            'address': address,
                            'store_name': store_name+' '+store_name2,
                            'brand': 'Cartier',
                            'country': country,
                            'is_partner': 0
                            }
                    rows_list.append(dict1)     
                else:
                    for multi in multis:
                        final_url = get_value(multi, config, 'urld')
                        final_url = re.sub('\.\./', '', final_url)
                        driver.get('https://stores.cartier.com/' + final_url)
                        page = get_page(driver)
                        #final_page
                        #collect
                        city = get_value(page, config, 'city')
                        address = get_value(page, config, 'address')
                        store_name = get_value(page, config, 'store_name')
                        store_name2 = get_value(page, config, 'store_name2')
                        dict1 = {'city': city,
                                'address': address,
                                'store_name': store_name+' '+store_name2,
                                'brand': 'Cartier',
                                'country': country,
                                'is_partner': 0
                                }
                        rows_list.append(dict1)     
            else:
                for item_lvl3 in items_lvl3:
                    url = get_value(item_lvl3, config, 'url')
                    new_url = 'https://stores.cartier.com/' + url
                    driver.get(new_url)
                    time.sleep(2)
                    page = get_page(driver)

                    items_lvl4 = get_items(driver, config["items"])
                    if len(items_lvl4) == 0:
                        multis = get_items(driver, config["multi"])
                        if len(multis) == 0:
                            #final_page
                            #collect
                            city = get_value(page, config, 'city')
                            address = get_value(page, config, 'address')
                            store_name = get_value(page, config, 'store_name')
                            store_name2 = get_value(page, config, 'store_name2')
                            dict1 = {'city': city,
                                    'address': address,
                                    'store_name': store_name+' '+store_name2,
                                    'brand': 'Cartier',
                                    'country': country,
                                    'is_partner': 0
                                    }
                            rows_list.append(dict1)     
                        else:
                            for multi in multis:
                                final_url = get_value(multi, config, 'urld')
                                final_url = re.sub('\.\./', '', final_url)
                                driver.get('https://stores.cartier.com/' + final_url)
                                page = get_page(driver)
                                #final_page
                                #collect
                                city = get_value(page, config, 'city')
                                address = get_value(page, config, 'address')
                                store_name = get_value(page, config, 'store_name')
                                store_name2 = get_value(page, config, 'store_name2')
                                dict1 = {'city': city,
                                        'address': address,
                                        'store_name': store_name+' '+store_name2,
                                        'brand': 'Cartier',
                                        'country': country,
                                        'is_partner': 0
                                        }
                                rows_list.append(dict1)
                                
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 270

# %%
len(df)
# Out:
# 270

# %%
df.head()
# Out:
#          city                          address  \
# 0  Oranjestad                 Renaissance Mall
# 1      Sydney            74 Castlereagh Street
# 2      Sydney  The Rocks ,   155 George Street
# 3    Brisbane                172 Edward Street
# 4   Chadstone           Ground Floor G066/1341
#
#                                           store_name    brand    country  \
# 0  Boutique Cartier Aruba Oranjestad - Renaissanc...  Cartier      Aruba
# 1  Boutique Cartier Sydney Flagship Sydney - 74 C...  Cartier  Australia
# 2  Boutique Cartier Boutique -DFS Galleria Sydney...  Cartier  Australia
# 3  Boutique Cartier Brisbane Brisbane - 172 Edwar...  Cartier  Australia
# 4  Boutique Cartier Chadstone Chadstone - Ground ...  Cartier  Australia
#
#    is_partner
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# RETAILERS

# %%
config = config_all['CARTIER_RETAILERS']

# %%
driver.get(config['start_url'][0])

# %% [markdown]
# - Click on Resellers to only extract Retailers
# - Cartier has no retailers for jewelry (only watches)

# %%
with open('./config/city_country.yaml', 'r', encoding='utf-8') as file:
    dict_cc = yaml.safe_load(file)

# %%
for ci, co in dict_cc.items():
    ci = re.sub(" ", "+", ci)
    co = re.sub(" ", "+", co)
    new_url = "https://stores.cartier.com/en_eu/search?q=" + str(ci) + "%2C+" + str(co) +"&category=storeLocatorSearch&r=500&storetype=true&watches=true"
    driver.get(new_url)
    time.sleep(3)

    items = get_items(driver, config["items"])

    for item in items:
        country = get_value(item, config, 'country')
        store_name = get_value(item, config, 'store_name')
        address = ', '.join(item.xpath(config['address']))
        city = get_value(item, config, 'city')

        rows_list.append({
            'country': country,
            'store_name': store_name,
            'city': city,
            'address': address,
            'brand': 'Cartier',
            'is_partner': '1'
        })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# total stores: 928

# %%
df.head()
# Out:
#          city                          address  \
# 0  Oranjestad                 Renaissance Mall
# 1      Sydney            74 Castlereagh Street
# 2      Sydney  The Rocks ,   155 George Street
# 3    Brisbane                172 Edward Street
# 4   Chadstone           Ground Floor G066/1341
#
#                                           store_name    brand    country  \
# 0  Boutique Cartier Aruba Oranjestad - Renaissanc...  Cartier      Aruba
# 1  Boutique Cartier Sydney Flagship Sydney - 74 C...  Cartier  Australia
# 2  Boutique Cartier Boutique -DFS Galleria Sydney...  Cartier  Australia
# 3  Boutique Cartier Brisbane Brisbane - 172 Edwar...  Cartier  Australia
# 4  Boutique Cartier Chadstone Chadstone - Ground ...  Cartier  Australia
#
#   is_partner
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
brand = 'CARTIER'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/CARTIER_092021.xlsx

# %% [markdown]
# # ROLEX

# %%
config = config_all['ROLEX']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# Go and make a random research

# %%
import pycountry
#! pip3 install pycountry #to install pycountry

#CREATE LIST OF COUNTRIES
s = []
for i in list(pycountry.countries):
    try:
        country = i.common_name
    except:
        country = i.name
    alpha_2 = i.alpha_2
    alpha_3 = i.alpha_3
    s.append({'country': country, 'alpha_2': alpha_2, 'alpha_3': alpha_3})
countries = pd.DataFrame(s)

countries.loc[countries['country']=='China', 'country'] = 'Mainland China'
countries.loc[countries['country']=='Virgin Islands, British', 'country'] = 'British Virgin Islands'
countries.loc[countries['country']=='Virgin Islands, U.S.', 'country'] = 'US Virgin Islands'
countries.loc[countries['country']=='Korea, Republic of', 'country'] = 'South Korea'
countries.loc[countries['country']=="Korea, Democratic People's Republic of", 'country'] = 'North Korea'
countries.loc[countries['country']=="Côte d'Ivoire", 'country'] = 'Ivory Coast'
countries.loc[countries['country']=='Iran, Islamic Republic of', 'country'] = 'Iran'
countries.loc[countries['country']=="Lao People's Democratic Republic", 'country'] = 'Laos'
countries.loc[countries['country']=="Russian Federation", 'country'] = 'Russia'
countries.loc[countries['country']=="Hong Kong", 'country'] = 'Hong Kong SAR'
countries.loc[countries['country']=="Taiwan", 'country'] = 'Taiwan Region'
countries.loc[countries['country']=="Macao", 'country'] = 'Macau SAR'


countries_list = list(countries['country'].unique())

# %%
countries_list
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Anguilla',
#  'Åland Islands',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antarctica',
#  'French Southern Territories',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Bonaire, Sint Eustatius and Saba',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Saint Barthélemy',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Cocos (Keeling) Islands',
#  'Switzerland',
#  'Chile',
#  'Mainland China',
#  'Ivory Coast',
#  'Cameroon',
#  'Congo, The Democratic Republic of the',
#  'Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Cuba',
#  'Curaçao',
#  'Christmas Island',
#  'Cayman Islands',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
#  'Western Sahara',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands (Malvinas)',
#  'France',
#  'Faroe Islands',
#  'Micronesia, Federated States of',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Guinea',
#  'Guadeloupe',
#  'Gambia',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Greenland',
#  'Guatemala',
#  'French Guiana',
#  'Guam',
#  'Guyana',
#  'Hong Kong SAR',
#  'Heard Island and McDonald Islands',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'Isle of Man',
#  'India',
#  'British Indian Ocean Territory',
#  'Ireland',
#  'Iran',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jersey',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Saint Kitts and Nevis',
#  'South Korea',
#  'Kuwait',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Macau SAR',
#  'Saint Martin (French part)',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Madagascar',
#  'Maldives',
#  'Mexico',
#  'Marshall Islands',
#  'North Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Montenegro',
#  'Mongolia',
#  'Northern Mariana Islands',
#  'Mozambique',
#  'Mauritania',
#  'Montserrat',
#  'Martinique',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'Mayotte',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Niue',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Pitcairn',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Puerto Rico',
#  'North Korea',
#  'Portugal',
#  'Paraguay',
#  'Palestine, State of',
#  'French Polynesia',
#  'Qatar',
#  'Réunion',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'South Georgia and the South Sandwich Islands',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'Svalbard and Jan Mayen',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'San Marino',
#  'Somalia',
#  'Saint Pierre and Miquelon',
#  'Serbia',
#  'South Sudan',
#  'Sao Tome and Principe',
#  'Suriname',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Eswatini',
#  'Sint Maarten (Dutch part)',
#  'Seychelles',
#  'Syrian Arab Republic',
#  'Turks and Caicos Islands',
#  'Chad',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Turkmenistan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Tuvalu',
#  'Taiwan Region',
#  'Tanzania',
#  'Uganda',
#  'Ukraine',
#  'United States Minor Outlying Islands',
#  'Uruguay',
#  'United States',
#  'Uzbekistan',
#  'Holy See (Vatican City State)',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'US Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Yemen',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
countries_list_l = countries_list

for e, country in enumerate(countries_list_l):
    country = str(country).lower()
    country = re.sub(' ', '', country)
    country = re.sub('\.', '', country)
    country = re.sub('(frenchpart)', '', country)
    country = re.sub('(dutchpart)', '', country)
    country = re.sub('è', 'e', country)
    country = re.sub('é', 'e', country)
    country = country.strip()
    url = 'https://www.rolex.com/rolex-dealers/' + country + '.html#mode=list'
    driver.get(url)
    time.sleep(5)
    #driver.execute_script("window.stop();")
    items = get_items(driver, config["items"])
    print(e+1, '-', len(items), 'stores found for', country)
    
    for item in items:
        store_name = get_value(item, config, 'store_name')
        info1 = get_value(item, config, 'info1')
        info2 = get_value(item, config, 'info2')
        info3 = get_value(item, config, 'info3')
        info4 = get_value(item, config, 'info4')
        info5 = get_value(item, config, 'info5')

        rows_list.append({
            'url': driver.current_url,
            'store_name': store_name,
            'info1': info1,
            'info2': info2,
            'info3': info3,
            'info4': info4,
            'info5': info5,
            'brand': 'Rolex'
        })
        #print(rows_list)
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(subset=['brand', 'info1', 'info2', 'info3', 'info4', 'info5', 'store_name'], inplace=True)
print('total stores:', len(df))
# Out:
# 1 - 1 stores found for aruba
# 2 - 0 stores found for afghanistan
# 3 - 0 stores found for angola
# 4 - 0 stores found for anguilla
# 5 - 0 stores found for ålandislands
# 6 - 0 stores found for albania
# 7 - 2 stores found for andorra
# 8 - 24 stores found for unitedarabemirates
# 9 - 10 stores found for argentina
# 10 - 0 stores found for armenia
# 11 - 0 stores found for americansamoa
# 12 - 0 stores found for antarctica
# 13 - 0 stores found for frenchsouthernterritories
# 14 - 1 stores found for antiguaandbarbuda
# 15 - 21 stores found for australia
# 16 - 15 stores found for austria
# 17 - 2 stores found for azerbaijan
# 18 - 0 stores found for burundi
# 19 - 13 stores found for belgium
# 20 - 0 stores found for benin
# 21 - 0 stores found for bonaire,sinteustatiusandsaba
# 22 - 0 stores found for burkinafaso
# 23 - 0 stores found for bangladesh
# 24 - 1 stores found for bulgaria
# 25 - 3 stores found for bahrain
# 26 - 4 stores found for bahamas
# 27 - 0 stores found for bosniaandherzegovina
# 28 - 1 stores found for saintbarthelemy
# 29 - 0 stores found for belarus
# 30 - 0 stores found for belize
# 31 - 1 stores found for bermuda
# 32 - 1 stores found for bolivia
# 33 - 20 stores found for brazil
# 34 - 1 stores found for barbados
# 35 - 1 stores found for bruneidarussalam
# 36 - 0 stores found for bhutan
# 37 - 0 stores found for bouvetisland
# 38 - 0 stores found for botswana
# 39 - 0 stores found for centralafricanrepublic
# 40 - 29 stores found for canada
# 41 - 0 stores found for cocos(keeling)islands
# 42 - 35 stores found for switzerland
# 43 - 6 stores found for chile
# 44 - 108 stores found for mainlandchina
# 45 - 2 stores found for ivorycoast
# 46 - 0 stores found for cameroon
# 47 - 0 stores found for congo,thedemocraticrepublicofthe
# 48 - 0 stores found for congo
# 49 - 0 stores found for cookislands
# 50 - 7 stores found for colombia
# 51 - 0 stores found for comoros
# 52 - 0 stores found for caboverde
# 53 - 2 stores found for costarica
# 54 - 0 stores found for cuba
# 55 - 0 stores found for curaçao
# 56 - 0 stores found for christmasisland
# 57 - 2 stores found for caymanislands
# 58 - 2 stores found for cyprus
# 59 - 0 stores found for czechia
# 60 - 136 stores found for germany
# 61 - 0 stores found for djibouti
# 62 - 1 stores found for dominica
# 63 - 7 stores found for denmark
# 64 - 3 stores found for dominicanrepublic
# 65 - 1 stores found for algeria
# 66 - 1 stores found for ecuador
# 67 - 3 stores found for egypt
# 68 - 0 stores found for eritrea
# 69 - 0 stores found for westernsahara
# 70 - 48 stores found for spain
# 71 - 0 stores found for estonia
# 72 - 0 stores found for ethiopia
# 73 - 3 stores found for finland
# 74 - 1 stores found for fiji
# 75 - 0 stores found for falklandislands(malvinas)
# 76 - 61 stores found for france
# 77 - 0 stores found for faroeislands
# 78 - 0 stores found for micronesia,federatedstatesof
# 79 - 0 stores found for gabon
# 80 - 102 stores found for unitedkingdom
# 81 - 0 stores found for georgia
# 82 - 0 stores found for guernsey
# 83 - 0 stores found for ghana
# 84 - 1 stores found for gibraltar
# 85 - 0 stores found for guinea
# 86 - 1705 stores found for guadeloupe
# 87 - 0 stores found for gambia
# 88 - 0 stores found for guinea-bissau
# 89 - 0 stores found for equatorialguinea
# 90 - 33 stores found for greece
# 91 - 0 stores found for grenada
# 92 - 0 stores found for greenland
# 93 - 2 stores found for guatemala
# 94 - 0 stores found for frenchguiana
# 95 - 2 stores found for guam
# 96 - 0 stores found for guyana
# 97 - 47 stores found for hongkongsar
# 98 - 0 stores found for heardislandandmcdonaldislands
# 99 - 0 stores found for honduras
# 100 - 2 stores found for croatia
# 101 - 0 stores found for haiti
# 102 - 1 stores found for hungary
# 103 - 10 stores found for indonesia
# 104 - 0 stores found for isleofman
# 105 - 23 stores found for india
# 106 - 0 stores found for britishindianoceanterritory
# 107 - 3 stores found for ireland
# 108 - 2 stores found for iran
# 109 - 0 stores found for iraq
# 110 - 1 stores found for iceland
# 111 - 5 stores found for israel
# 112 - 139 stores found for italy
# 113 - 3 stores found for jamaica
# 114 - 0 stores found for jersey
# 115 - 1 stores found for jordan
# 116 - 67 stores found for japan
# 117 - 2 stores found for kazakhstan
# 118 - 0 stores found for kenya
# 119 - 0 stores found for kyrgyzstan
# 120 - 0 stores found for cambodia
# 121 - 0 stores found for kiribati
# 122 - 0 stores found for saintkittsandnevis
# 123 - 16 stores found for southkorea
# 124 - 4 stores found for kuwait
# 125 - 0 stores found for laos
# 126 - 1 stores found for lebanon
# 127 - 0 stores found for liberia
# 128 - 2 stores found for libya
# 129 - 1 stores found for saintlucia
# 130 - 2 stores found for liechtenstein
# 131 - 3 stores found for srilanka
# 132 - 0 stores found for lesotho
# 133 - 0 stores found for lithuania
# 134 - 2 stores found for luxembourg
# 135 - 0 stores found for latvia
# 136 - 9 stores found for macausar
# 137 - 0 stores found for saintmartin()
# 138 - 4 stores found for morocco
# 139 - 2 stores found for monaco
# 140 - 0 stores found for moldova
# 141 - 0 stores found for madagascar
# 142 - 0 stores found for maldives
# 143 - 35 stores found for mexico
# 144 - 0 stores found for marshallislands
# 145 - 0 stores found for northmacedonia
# 146 - 0 stores found for mali
# 147 - 2 stores found for malta
# 148 - 1 stores found for myanmar
# 149 - 1 stores found for montenegro
# 150 - 1 stores found for mongolia
# 151 - 0 stores found for northernmarianaislands
# 152 - 0 stores found for mozambique
# 153 - 0 stores found for mauritania
# 154 - 0 stores found for montserrat
# 155 - 0 stores found for martinique
# 156 - 3 stores found for mauritius
# 157 - 0 stores found for malawi
# 158 - 17 stores found for malaysia
# 159 - 0 stores found for mayotte
# 160 - 1 stores found for namibia
# 161 - 0 stores found for newcaledonia
# 162 - 0 stores found for niger
# 163 - 0 stores found for norfolkisland
# 164 - 3 stores found for nigeria
# 165 - 0 stores found for nicaragua
# 166 - 0 stores found for niue
# 167 - 13 stores found for netherlands
# 168 - 6 stores found for norway
# 169 - 1 stores found for nepal
# 170 - 0 stores found for nauru
# 171 - 6 stores found for newzealand
# 172 - 2 stores found for oman
# 173 - 3 stores found for pakistan
# 174 - 2 stores found for panama
# 175 - 0 stores found for pitcairn
# 176 - 2 stores found for peru
# 177 - 11 stores found for philippines
# 178 - 0 stores found for palau
# 179 - 0 stores found for papuanewguinea
# 180 - 10 stores found for poland
# 181 - 1 stores found for puertorico
# 182 - 0 stores found for northkorea
# 183 - 12 stores found for portugal
# 184 - 1 stores found for paraguay
# 185 - 0 stores found for palestine,stateof
# 186 - 0 stores found for frenchpolynesia
# 187 - 2 stores found for qatar
# 188 - 0 stores found for reunion
# 189 - 2 stores found for romania
# 190 - 19 stores found for russia
# 191 - 0 stores found for rwanda
# 192 - 18 stores found for saudiarabia
# 193 - 0 stores found for sudan
# 194 - 0 stores found for senegal
# 195 - 19 stores found for singapore
# 196 - 0 stores found for southgeorgiaandthesouthsandwichislands
# 197 - 0 stores found for sainthelena,ascensionandtristandacunha
# 198 - 0 stores found for svalbardandjanmayen
# 199 - 0 stores found for solomonislands
# 200 - 0 stores found for sierraleone
# 201 - 1 stores found for elsalvador
# 202 - 0 stores found for sanmarino
# 203 - 0 stores found for somalia
# 204 - 0 stores found for saintpierreandmiquelon
# 205 - 1 stores found for serbia
# 206 - 0 stores found for southsudan
# 207 - 0 stores found for saotomeandprincipe
# 208 - 0 stores found for suriname
# 209 - 1 stores found for slovakia
# 210 - 1 stores found for slovenia
# 211 - 7 stores found for sweden
# 212 - 0 stores found for eswatini
# 213 - 0 stores found for sintmaarten()
# 214 - 0 stores found for seychelles
# 215 - 0 stores found for syrianarabrepublic
# 216 - 1 stores found for turksandcaicosislands
# 217 - 0 stores found for chad
# 218 - 0 stores found for togo
# 219 - 19 stores found for thailand
# 220 - 0 stores found for tajikistan
# 221 - 0 stores found for tokelau
# 222 - 0 stores found for turkmenistan
# 223 - 0 stores found for timor-leste
# 224 - 0 stores found for tonga
# 225 - 0 stores found for trinidadandtobago
# 226 - 2 stores found for tunisia
# 227 - 14 stores found for turkey
# 228 - 0 stores found for tuvalu
# 229 - 21 stores found for taiwanregion
# 230 - 0 stores found for tanzania
# 231 - 0 stores found for uganda
# 232 - 1 stores found for ukraine
# 233 - 0 stores found for unitedstatesminoroutlyingislands
# 234 - 3 stores found for uruguay
# 235 - 336 stores found for unitedstates
# 236 - 0 stores found for uzbekistan
# 237 - 0 stores found for holysee(vaticancitystate)
# 238 - 0 stores found for saintvincentandthegrenadines
# 239 - 8 stores found for venezuela
# 240 - 1 stores found for britishvirginislands
# 241 - 1 stores found for usvirginislands
# 242 - 2 stores found for vietnam
# 243 - 1 stores found for vanuatu
# 244 - 0 stores found for wallisandfutuna
# 245 - 0 stores found for samoa
# 246 - 3 stores found for yemen
# 247 - 10 stores found for southafrica
# 248 - 0 stores found for zambia
# 249 - 0 stores found for zimbabwe
# total stores: 1705

# %%
#correct manually some wrongly scraped info (not necessary)
items = get_items(driver, config["items"])
print(len(items), 'stores found')

for item in items:
    store_name = get_value(item, config, 'store_name')
    info1 = get_value(item, config, 'info1')
    info2 = get_value(item, config, 'info2')
    info3 = get_value(item, config, 'info3')
    info4 = get_value(item, config, 'info4')
    info5 = get_value(item, config, 'info5')

    rows_list.append({
        'url': driver.current_url,
        'store_name': store_name,
        'info1': info1,
        'info2': info2,
        'info3': info3,
        'info4': info4,
        'info5': info5,
        'brand': 'Rolex'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(subset=['brand', 'info1', 'info2', 'info3', 'info4', 'info5', 'store_name'], inplace=True)
print('total stores:', len(df))
# Out:
# 0 stores found
# total stores: 1707

# %%
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Rolex'))

# %%
df
# Out:
#                                                     url  \
# 0     https://www.rolex.com/rolex-dealers/aruba.html...
# 1     https://www.rolex.com/rolex-dealers/andorra.ht...
# 2     https://www.rolex.com/rolex-dealers/andorra.ht...
# 3     https://www.rolex.com/rolex-dealers/unitedarab...
# 4     https://www.rolex.com/rolex-dealers/unitedarab...
# ...                                                 ...
# 2377  https://www.rolex.com/rolex-dealers/guadeloupe...
# 2383  https://www.rolex.com/rolex-dealers/guadeloupe...
# 2384  https://www.rolex.com/rolex-dealers/guadeloupe...
# 2385  https://www.rolex.com/rolex-dealers/guadeloupe...
# 2387  https://www.rolex.com/rolex-dealers/guadeloupe...
#
#                                          store_name  \
# 0                                       ‭Gandelman‬
# 1                                   ‭JOIERIA BERNA‬
# 2                                  ‭JOIERIA GENEVE‬
# 3     ‭Mohammed Rasool Khoory & Sons Galleria Mall‬
# 4                   ‭Mohammed Rasool Khoory & Sons‬
# ...                                             ...
# 2377                               ‭ZEGG & CERLATI‬
# 2383                                       ‭Zimson‬
# 2384          ‭Zong Chong Watch Co. - Bo Ai Branch‬
# 2385     ‭Zong Chong Watch Co. - Zhong Xiao Branch‬
# 2387                       ‭Zurich Watch Co., Ltd.‬
#
#                                             info1  \
# 0       Renaissance Mall, 82 L.G. Smith Boulevard
# 1                        Avenida Meritxell  51-55
# 2                          Avenida Meritxell  124
# 3                   The Galleria Al Maryah Island
# 4     Abu Dhabi International Airport, Terminal 3
# ...                                           ...
# 2377                            1 Place du Casino
# 2383                           128-A, Race Course
# 2384                               154 Bo’ai Rd.,
# 2385                508 Sec. 4, Zhongxiao E. Rd.,
# 2387                                          G/F
#
#                                 info2                 info3          info4  \
# 0                    Oranjestad 00000                 Aruba           None
# 1              AD500 Andorra la Vella               Andorra        Andorra
# 2              AD500 Andorra la Vella               Andorra        Andorra
# 3               P.O Box 126 Abu Dhabi  United Arab Emirates           None
# 4             P.O. Box: 126 Abu Dhabi  United Arab Emirates           None
# ...                               ...                   ...            ...
# 2377                     98000 MONACO                  None           None
# 2383            Coimbatore Tamil Nadu                641018          India
# 2384  Taipei City Zhongzheng District                 10043  Taiwan Region
# 2385       Taipei City Xinyi District                 11071  Taiwan Region
# 2387                91-93 Nathan Road         Tsim Sha Tsui  Hong Kong SAR
#
#      info5  brand  is_partner
# 0     None  Rolex           1
# 1     None  Rolex           1
# 2     None  Rolex           1
# 3     None  Rolex           1
# 4     None  Rolex           1
# ...    ...    ...         ...
# 2377  None  Rolex           1
# 2383  None  Rolex           1
# 2384  None  Rolex           1
# 2385  None  Rolex           1
# 2387  None  Rolex           1
#
# [1705 rows x 9 columns]

# %%
len(df)
# Out:
# 1705

# %%
brand = 'ROLEX'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/ROLEX_092021.xlsx

# %% [markdown]
# # TAG HEUER

# %%
config = config_all['TAGHEUER']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = get_items(driver, config["country_code"])
print(len(country_codes))

for country in country_codes:
    
    print(country)
    url = "https://www.tagheuer.com/" + country
    driver.get(url)
    time.sleep(3)
    
    items = get_items(driver, config["items"])
    for item in items:
        store_name = get_value(item, config, 'store_name')
        store_address1 = get_value(item, config, 'store_address1')
        store_address2 = get_value(item, config, 'store_address2')
        store_address3 = get_value(item, config, 'store_address3')
        rows_list.append({
                'store_name': store_name,
                'store_address1': store_address1,
                'store_address2': store_address2,
                'store_address3': store_address3,
                'brand': "Tag Heuer"
            })

df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Tag Heuer'))
# Out:
# 40
# /fr/en/stores/ar
# /fr/en/stores/au
# /fr/en/stores/at
# /fr/en/stores/be
# /fr/en/stores/br
# /fr/en/stores/ca
# /fr/en/stores/cn
# /fr/en/stores/co
# /fr/en/stores/hr
# /fr/en/stores/cz
# /fr/en/stores/dk
# /fr/en/stores/fi
# /fr/en/stores/fr
# /fr/en/stores/de
# /fr/en/stores/gr
# /fr/en/stores/hk
# /fr/en/stores/in
# /fr/en/stores/id
# /fr/en/stores/il
# /fr/en/stores/it
# /fr/en/stores/jp
# /fr/en/stores/my
# /fr/en/stores/mx
# /fr/en/stores/nl
# /fr/en/stores/no
# /fr/en/stores/pl
# /fr/en/stores/pt
# /fr/en/stores/ru
# /fr/en/stores/sa
# /fr/en/stores/sg
# /fr/en/stores/za
# /fr/en/stores/kr
# /fr/en/stores/es
# /fr/en/stores/se
# /fr/en/stores/ch
# /fr/en/stores/tw
# /fr/en/stores/tr
# /fr/en/stores/ae
# /fr/en/stores/gb
# /fr/en/stores/us
# total stores: 2719

# %%
len(df)
# Out:
# 2719

# %%
brand = 'TAGHEUER'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/TAGHEUER_092021.xlsx

# %% [markdown]
# # ZENITH

# %%
config = config_all['ZENITH']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = get_items(driver, config["country_code"])
print("Number of countries=",len(country_codes))

for idx, country_code in enumerate(country_codes):
    print(country_code)
    url = "https://www.zenith-watches.com/en_us/store-locator?filter=official,retailer&store=&country=" + country_code + "&address=&latlng="
    #print(url)
    driver.get(url)
    time.sleep(3)
    
    items = get_items(driver, config["items"])
    
    for item in items:
        store_name = get_value(item,config,'store_name')
        store_address1 = get_value(item,config,'store_address1') 
        store_address2 = get_value(item,config,'store_address2')
        store_address3 = get_value(item,config,'store_address3')
        rows_list.append({
                'store_name': store_name,
                'store_address1': store_address1,
                'store_address2': store_address2,
                'store_address3': store_address3,
                'brand': "Zenith"
            })
            
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))    
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Zenith'))
# Out:
# Number of countries= 95
# AD
# AO
# AR
# AM
# AW
# AU
# AT
# AZ
# BS
# BH
# BD
# BY
# BE
# BM
# VG
# BG
# CA
# KY
# CN
# CO
# CR
# HR
# CY
# CZ
# DK
# DO
# EG
# EE
# FI
# FR
# GE
# DE
# GR
# GU
# GT
# HK
# HU
# IN
# ID
# IE
# IL
# IT
# JM
# JP
# KZ
# KE
# KW
# KG
# LV
# LB
# LT
# LU
# MO
# MY
# MV
# MT
# MU
# MX
# MC
# MA
# NP
# NL
# NG
# MP
# NO
# OM
# PY
# PE
# PH
# PL
# PT
# QA
# RO
# RU
# RS
# SG
# SK
# SI
# ZA
# KR
# ES
# KN
# MF
# SE
# CH
# TW
# TH
# TR
# TM
# UA
# AE
# GB
# US
# UZ
# VE
# total stores: 667

# %%
len(df)
# Out:
# 667

# %%
brand = 'ZENITH'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/ZENITH_092021.xlsx

# %% [markdown]
# # OMEGA

# %%
config = config_all['OMEGA']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = get_items(driver, config["country_code"])
print("Number of countries=",len(country_codes))

for country_code in country_codes:
    driver.get(country_code)
    time.sleep(3)

    city_codes = get_items(driver,config["city_code"])
    for city_code in city_codes:
        print(city_code)
        driver.get(city_code)
        time.sleep(3)   
        #Need to scroll down to load more elements
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)
        
        items = get_items(driver, config["items"])
        print("Items=",len(items),"\n")

        for item in items:
            rows_list.append({
                    'store_name': get_value(item,config,'store_name'),
                    'store_address1': get_value(item,config,'store_address1'),
                    'store_address2': get_value(item,config,'store_address2'),
                    'store_address3': get_value(item,config,'store_address3'),
                    'store_address4': get_value(item,config,'store_address4'),
                    'store_address5': get_value(item,config,'store_address5'),
                    'store_address6': get_value(item,config,'store_address6'),
                    'store_address7': get_value(item,config,'store_address7'),
                    'brand': "Omega"
                })
            
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Omega'))
# Out:
# Number of countries= 129
# https://www.omegawatches.com/store/country/algeria/city/dz-alger
# Items= 4
#
# https://www.omegawatches.com/store/country/algeria/city/oran
# Items= 2
#
# https://www.omegawatches.com/store/country/andorra/city/andorra-la-vella
# Items= 2
#
# https://www.omegawatches.com/store/country/angola/city/luanda
# Items= 1
#
# https://www.omegawatches.com/store/country/antigua-and-barbuda/city/st-john's
# Items= 1
#
# https://www.omegawatches.com/store/country/argentina/city/bahia-blanca
# Items= 1
#
# https://www.omegawatches.com/store/country/argentina/city/buenos-aires
# Items= 7
#
# https://www.omegawatches.com/store/country/argentina/city/cordoba
# Items= 1
#
# https://www.omegawatches.com/store/country/argentina/city/rosario
# Items= 1
#
# https://www.omegawatches.com/store/country/aruba/city/noord
# Items= 1
#
# https://www.omegawatches.com/store/country/aruba/city/oranjestad
# Items= 2
#
# https://www.omegawatches.com/store/country/aruba/city/palm-beach
# Items= 1
#
# https://www.omegawatches.com/store/country/australia/city/adelaide
# Items= 1
#
# https://www.omegawatches.com/store/country/australia/city/brisbane
# Items= 2
#
# https://www.omegawatches.com/store/country/australia/city/cairns
# Items= 1
#
# https://www.omegawatches.com/store/country/australia/city/gold-coast
# Items= 2
#
# https://www.omegawatches.com/store/country/australia/city/melbourne
# Items= 5
#
# https://www.omegawatches.com/store/country/australia/city/perth
# Items= 2
#
# https://www.omegawatches.com/store/country/australia/city/sydney
# Items= 5
#
# https://www.omegawatches.com/store/country/australia/city/sydney-international-airport
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/dornbirn
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/eisenstadt
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/graz
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/innsbruck
# Items= 2
#
# https://www.omegawatches.com/store/country/austria/city/ischgl
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/klagenfurt
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/leoben
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/linz
# Items= 2
#
# https://www.omegawatches.com/store/country/austria/city/salzburg
# Items= 3
#
# https://www.omegawatches.com/store/country/austria/city/wels
# Items= 1
#
# https://www.omegawatches.com/store/country/austria/city/wien
# Items= 5
#
# https://www.omegawatches.com/store/country/azerbaijan/city/baku
# Items= 2
#
# https://www.omegawatches.com/store/country/bahamas/city/nassau
# Items= 3
#
# https://www.omegawatches.com/store/country/bahamas/city/paradise-island
# Items= 1
#
# https://www.omegawatches.com/store/country/bahrain/city/manama
# Items= 8
#
# https://www.omegawatches.com/store/country/bangladesh/city/dhaka
# Items= 3
#
# https://www.omegawatches.com/store/country/barbados/city/bridgetown
# Items= 1
#
# https://www.omegawatches.com/store/country/belarus/city/minsk
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/aalst
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/antwerpen
# Items= 2
#
# https://www.omegawatches.com/store/country/belgium/city/brugge
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/bruxelles
# Items= 2
#
# https://www.omegawatches.com/store/country/belgium/city/de-haan
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/gent
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/hasselt
# Items= 2
#
# https://www.omegawatches.com/store/country/belgium/city/heist-op-den-berg
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/knokke
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/kortrijk
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/leuven
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/liege
# Items= 2
#
# https://www.omegawatches.com/store/country/belgium/city/namur
# Items= 2
#
# https://www.omegawatches.com/store/country/belgium/city/waregem
# Items= 1
#
# https://www.omegawatches.com/store/country/belgium/city/waterloo
# Items= 1
#
# https://www.omegawatches.com/store/country/bermuda/city/hamilton
# Items= 2
#
# https://www.omegawatches.com/store/country/bolivia/city/santa-cruz-de-la-sierra
# Items= 1
#
# https://www.omegawatches.com/store/country/brazil/city/belo-horizonte
# Items= 3
#
# https://www.omegawatches.com/store/country/brazil/city/brasilia
# Items= 1
#
# https://www.omegawatches.com/store/country/brazil/city/curitiba
# Items= 2
#
# https://www.omegawatches.com/store/country/brazil/city/fortaleza
# Items= 2
#
# https://www.omegawatches.com/store/country/brazil/city/porto-alegre
# Items= 1
#
# https://www.omegawatches.com/store/country/brazil/city/sao-jose-do-rio-preto
# Items= 1
#
# https://www.omegawatches.com/store/country/brazil/city/sao-paulo
# Items= 1
#
# https://www.omegawatches.com/store/country/british-virgin-islands/city/road-town
# Items= 1
#
# https://www.omegawatches.com/store/country/brunei-darussalam/city/brunei
# Items= 1
#
# https://www.omegawatches.com/store/country/bulgaria/city/sofia
# Items= 2
#
# https://www.omegawatches.com/store/country/cambodia/city/phnom-penh
# Items= 2
#
# https://www.omegawatches.com/store/country/cambodia/city/siem-reap
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/burnaby
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/calgary
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/cambridge
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/edmonton
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/etobicoke
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/halifax
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/hamilton
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/langley
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/markham
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/mississauga
# Items= 2
#
# https://www.omegawatches.com/store/country/canada/city/montreal
# Items= 2
#
# https://www.omegawatches.com/store/country/canada/city/oakville
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/oshawa
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/ottawa
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/quebec-city
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/richmond
# Items= 3
#
# https://www.omegawatches.com/store/country/canada/city/st-john's
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/toronto
# Items= 5
#
# https://www.omegawatches.com/store/country/canada/city/vancouver
# Items= 3
#
# https://www.omegawatches.com/store/country/canada/city/victoria
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/waterloo
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/west-vancouver
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/windsor
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/winnipeg
# Items= 1
#
# https://www.omegawatches.com/store/country/canada/city/woodbridge
# Items= 1
#
# https://www.omegawatches.com/store/country/cayman-islands/city/george-town
# Items= 4
#
# https://www.omegawatches.com/store/country/chile/city/santiago-de-chile
# Items= 5
#
# https://www.omegawatches.com/store/country/colombia/city/barranquilla
# Items= 1
#
# https://www.omegawatches.com/store/country/colombia/city/bogota
# Items= 3
#
# https://www.omegawatches.com/store/country/colombia/city/cali
# Items= 1
#
# https://www.omegawatches.com/store/country/congo/city/brazzaville
# Items= 1
#
# https://www.omegawatches.com/store/country/congo/city/pointe-noire
# Items= 1
#
# https://www.omegawatches.com/store/country/cook-islands/city/raratonga
# Items= 1
#
# https://www.omegawatches.com/store/country/costa-rica/city/san-jose
# Items= 1
#
# https://www.omegawatches.com/store/country/croatia/city/split
# Items= 1
#
# https://www.omegawatches.com/store/country/croatia/city/zagreb
# Items= 2
#
# https://www.omegawatches.com/store/country/cyprus/city/larnaca
# Items= 2
#
# https://www.omegawatches.com/store/country/cyprus/city/limassol
# Items= 2
#
# https://www.omegawatches.com/store/country/cyprus/city/nicosia
# Items= 1
#
# https://www.omegawatches.com/store/country/cyprus/city/paphos
# Items= 1
#
# https://www.omegawatches.com/store/country/czech-republic/city/brno
# Items= 1
#
# https://www.omegawatches.com/store/country/czech-republic/city/karlovy-vary
# Items= 1
#
# https://www.omegawatches.com/store/country/czech-republic/city/ostrava-1
# Items= 1
#
# https://www.omegawatches.com/store/country/czech-republic/city/praha
# Items= 2
#
# https://www.omegawatches.com/store/country/denmark/city/aalborg
# Items= 1
#
# https://www.omegawatches.com/store/country/denmark/city/arhus-c
# Items= 1
#
# https://www.omegawatches.com/store/country/denmark/city/hellerup
# Items= 1
#
# https://www.omegawatches.com/store/country/denmark/city/kobenhavn
# Items= 1
#
# https://www.omegawatches.com/store/country/denmark/city/kobenhavn-k
# Items= 3
#
# https://www.omegawatches.com/store/country/denmark/city/odense
# Items= 1
#
# https://www.omegawatches.com/store/country/dominican-republic/city/punta-cana
# Items= 1
#
# https://www.omegawatches.com/store/country/ecuador/city/guayaquil
# Items= 1
#
# https://www.omegawatches.com/store/country/ecuador/city/quito
# Items= 1
#
# https://www.omegawatches.com/store/country/egypt/city/alexandria
# Items= 1
#
# https://www.omegawatches.com/store/country/egypt/city/cairo
# Items= 6
#
# https://www.omegawatches.com/store/country/finland/city/helsinki
# Items= 3
#
# https://www.omegawatches.com/store/country/finland/city/oulu
# Items= 1
#
# https://www.omegawatches.com/store/country/finland/city/vantaa
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/aix-en-provence
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/ajaccio
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/avignon
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/bastia
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/biarritz
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/bordeaux
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/cannes
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/cap-ferret
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/deauville
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/dunkerque
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/grenoble
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/la-rochelle
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/le-kremlin-bicetre
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/lille
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/lyon
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/marseille
# Items= 3
#
# https://www.omegawatches.com/store/country/france/city/metz
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/montpellier
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/mulhouse
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/nancy
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/nantes
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/nice
# Items= 4
#
# https://www.omegawatches.com/store/country/france/city/orly
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/paris
# Items= 15
#
# https://www.omegawatches.com/store/country/france/city/quimper
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/reims
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/rennes
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/roissy
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/rouen
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/royan
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/saint-etienne
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/saint-laurent-du-var
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/saint-tropez
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/strasbourg
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/toulon
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/toulouse
# Items= 2
#
# https://www.omegawatches.com/store/country/france/city/tours
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/val-d'isere
# Items= 1
#
# https://www.omegawatches.com/store/country/france/city/vannes
# Items= 1
#
# https://www.omegawatches.com/store/country/georgia/city/tbilisi
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/aachen
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/augsburg
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/bad-oeynhausen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/bad-worishofen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/bamberg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/bayreuth
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/berlin
# Items= 5
#
# https://www.omegawatches.com/store/country/germany/city/bielefeld
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/bochum
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/bonn
# Items= 3
#
# https://www.omegawatches.com/store/country/germany/city/bremen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/chemnitz
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/coburg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/darmstadt
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/dortmund
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/dresden
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/dusseldorf
# Items= 5
#
# https://www.omegawatches.com/store/country/germany/city/erfurt
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/essen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/esslingen-am-neckar
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/fellbach
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/frankfurt-am-main
# Items= 6
#
# https://www.omegawatches.com/store/country/germany/city/freiburg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/garmisch-partenkirchen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/giessen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/hamburg
# Items= 5
#
# https://www.omegawatches.com/store/country/germany/city/hamm
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/heilbronn
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/kampen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/karlsruhe
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/kempten
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/kiel
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/koblenz
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/koln
# Items= 3
#
# https://www.omegawatches.com/store/country/germany/city/krefeld
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/landshut
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/leipzig
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/lippstadt
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/lubeck
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/ludenscheid
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/luneburg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/magdeburg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/mainz
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/mannheim
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/marl
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/minden
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/monchengladbach
# Items= 3
#
# https://www.omegawatches.com/store/country/germany/city/mulheim-an-der-ruhr
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/munchen
# Items= 5
#
# https://www.omegawatches.com/store/country/germany/city/munster
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/neuss
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/neustadt
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/nurnberg
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/oberhausen
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/oberstaufen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/oberstdorf
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/oldenburg
# Items= 2
#
# https://www.omegawatches.com/store/country/germany/city/osnabruck
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/posthausen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/recklinghausen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/reutlingen
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/rottach-egern
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/saarbrucken
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/st-ingbert
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/stuttgart
# Items= 3
#
# https://www.omegawatches.com/store/country/germany/city/sulzbach-taunus
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/timmendorfer-strand
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/titisee
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/trier
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/ulm
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/weimar
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/wetzlar
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/wiesbaden
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/wolfenbuttel
# Items= 1
#
# https://www.omegawatches.com/store/country/germany/city/wurzburg
# Items= 1
#
# https://www.omegawatches.com/store/country/gibraltar/city/gibraltar
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/athens
# Items= 5
#
# https://www.omegawatches.com/store/country/greece/city/glyfada
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/kallithea
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/kos
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/marousi
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/mykonos
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/n-ionia
# Items= 1
#
# https://www.omegawatches.com/store/country/greece/city/santorini
# Items= 2
#
# https://www.omegawatches.com/store/country/greece/city/thessaloniki
# Items= 3
#
# https://www.omegawatches.com/store/country/greece/city/zakinthos
# Items= 1
#
# https://www.omegawatches.com/store/country/guam/city/guam
# Items= 1
#
# https://www.omegawatches.com/store/country/guatemala/city/guatemala
# Items= 1
#
# https://www.omegawatches.com/store/country/hungary/city/budapest
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/ahmedabad
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/bengaluru
# Items= 4
#
# https://www.omegawatches.com/store/country/india/city/chandigarh
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/chennai
# Items= 2
#
# https://www.omegawatches.com/store/country/india/city/cochin
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/coimbaotre
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/gurgaon
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/hyderabad
# Items= 2
#
# https://www.omegawatches.com/store/country/india/city/indore
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/jaipur
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/kolkata
# Items= 2
#
# https://www.omegawatches.com/store/country/india/city/ludhiana
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/mumbai
# Items= 9
#
# https://www.omegawatches.com/store/country/india/city/new-delhi
# Items= 6
#
# https://www.omegawatches.com/store/country/india/city/noida
# Items= 1
#
# https://www.omegawatches.com/store/country/india/city/pune
# Items= 2
#
# https://www.omegawatches.com/store/country/indonesia/city/denpasar
# Items= 2
#
# https://www.omegawatches.com/store/country/indonesia/city/jakarta
# Items= 3
#
# https://www.omegawatches.com/store/country/indonesia/city/medan
# Items= 1
#
# https://www.omegawatches.com/store/country/indonesia/city/surabaya
# Items= 1
#
# https://www.omegawatches.com/store/country/iran/city/isfahan
# Items= 1
#
# https://www.omegawatches.com/store/country/iran/city/mashhad
# Items= 2
#
# https://www.omegawatches.com/store/country/iran/city/shiraz
# Items= 1
#
# https://www.omegawatches.com/store/country/iran/city/tehran
# Items= 13
#
# https://www.omegawatches.com/store/country/iraq/city/baghdad
# Items= 2
#
# https://www.omegawatches.com/store/country/ireland/city/codublin
# Items= 1
#
# https://www.omegawatches.com/store/country/ireland/city/county-cork
# Items= 1
#
# https://www.omegawatches.com/store/country/israel/city/haifa
# Items= 2
#
# https://www.omegawatches.com/store/country/israel/city/hod-hasharon
# Items= 1
#
# https://www.omegawatches.com/store/country/israel/city/nathanya
# Items= 1
#
# https://www.omegawatches.com/store/country/israel/city/ramat-gan
# Items= 1
#
# https://www.omegawatches.com/store/country/israel/city/tel-aviv
# Items= 5
#
# https://www.omegawatches.com/store/country/italy/city/alessandria
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/ancona
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/arezzo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/asolo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/bari
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/battipaglia
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/bergamo
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/biella
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/bologna
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/bolzano
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/brescia
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/brunico
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/cagliari
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/capri
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/caprona-pi
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/caserta
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/catania
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/civitanova-marche
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/como
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/conversano
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/cortina
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/cosenza
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/cremona
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/cuneo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/faenza
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/firenze
# Items= 3
#
# https://www.omegawatches.com/store/country/italy/city/fiumicino
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/foligno
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/forte-dei-marmi
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/frosinone
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/genova
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/gradisca-d'isonzo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/l'aquila
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/lecce
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/lecco
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/legnano
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/lignano-sabbiadoro
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/livigno
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/lucca
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/mantova
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/messina
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/milano
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/milano-marittima
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/modena
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/napoli
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/nettuno
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/padova
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/palermo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/parma
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/pavia
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/perugia
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/pescara
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/pisa
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/prato
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/ragusa
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/reggio-emilia
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/riccione
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/rimini
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/roma
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/salerno
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/salo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/sanremo
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/savona
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/seregno
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/siena
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/siracusa
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/spoleto
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/taormina
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/taranto
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/termini-imerese
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/terni
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/thiene
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/torino
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/trento
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/treviglio
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/treviso
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/udine
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/varese
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/venezia
# Items= 3
#
# https://www.omegawatches.com/store/country/italy/city/verbania
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/verona
# Items= 2
#
# https://www.omegawatches.com/store/country/italy/city/vicenza
# Items= 1
#
# https://www.omegawatches.com/store/country/italy/city/viterbo
# Items= 1
#
# https://www.omegawatches.com/store/country/jamaica/city/falmouth
# Items= 1
#
# https://www.omegawatches.com/store/country/jamaica/city/montego-bay
# Items= 2
#
# https://www.omegawatches.com/store/country/jamaica/city/ocho-rios
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/aichi
# Items= 5
#
# https://www.omegawatches.com/store/country/japan/city/aichi-chubu-international-airport
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/chiba
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/ehime
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/fukuoka
# Items= 4
#
# https://www.omegawatches.com/store/country/japan/city/fukuoka-international-airport
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/fukushima
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/hiroshima
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/hokkaido
# Items= 3
#
# https://www.omegawatches.com/store/country/japan/city/hyogo
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/ibaraki
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/ishikawa
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/iwate
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/kagawa
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/kagoshima
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/kanagawa
# Items= 3
#
# https://www.omegawatches.com/store/country/japan/city/kumamoto
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/kyoto
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/mie
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/miyagi
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/miyazaki
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/nagano
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/nagasaki
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/niigata
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/oita
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/okayama
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/okinawa
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/osaka
# Items= 6
#
# https://www.omegawatches.com/store/country/japan/city/osaka-kansai-international-airport
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/saitama
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/shizuoka
# Items= 3
#
# https://www.omegawatches.com/store/country/japan/city/tochigi
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/tokushima
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/tokyo
# Items= 17
#
# https://www.omegawatches.com/store/country/japan/city/tokyo-haneda-international-airport
# Items= 2
#
# https://www.omegawatches.com/store/country/japan/city/toyama
# Items= 1
#
# https://www.omegawatches.com/store/country/japan/city/yamaguchi
# Items= 1
#
# https://www.omegawatches.com/store/country/jordan/city/amman
# Items= 5
#
# https://www.omegawatches.com/store/country/kazakhstan/city/almaty
# Items= 3
#
# https://www.omegawatches.com/store/country/kazakhstan/city/astana
# Items= 1
#
# https://www.omegawatches.com/store/country/kazakhstan/city/khorgos
# Items= 1
#
# https://www.omegawatches.com/store/country/kenya/city/nairobi
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/al-jahra
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/al-rai
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/fahaheel
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/salhiya
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/salmiya
# Items= 1
#
# https://www.omegawatches.com/store/country/kuwait/city/sharq
# Items= 2
#
# https://www.omegawatches.com/store/country/kuwait/city/south-surra
# Items= 1
#
# https://www.omegawatches.com/store/country/laos/city/vientiane
# Items= 2
#
# https://www.omegawatches.com/store/country/latvia/city/riga
# Items= 1
#
# https://www.omegawatches.com/store/country/lebanon/city/beirut
# Items= 5
#
# https://www.omegawatches.com/store/country/lebanon/city/hazmieh
# Items= 1
#
# https://www.omegawatches.com/store/country/libya/city/benghazi
# Items= 2
#
# https://www.omegawatches.com/store/country/libya/city/tripoli
# Items= 3
#
# https://www.omegawatches.com/store/country/liechtenstein/city/vaduz
# Items= 2
#
# https://www.omegawatches.com/store/country/lithuania/city/vilnius
# Items= 1
#
# https://www.omegawatches.com/store/country/luxembourg/city/luxembourg
# Items= 3
#
# https://www.omegawatches.com/store/country/macau-sar/city/cotai-strip
# Items= 6
#
# https://www.omegawatches.com/store/country/macau-sar/city/macau-peninsula
# Items= 4
#
# https://www.omegawatches.com/store/country/macau-sar/city/taipa
# Items= 1
#
# https://www.omegawatches.com/store/country/macedonia/city/skopje
# Items= 1
#
# https://www.omegawatches.com/store/country/malaysia/city/johor-darul-takzim
# Items= 2
#
# https://www.omegawatches.com/store/country/malaysia/city/kota-kinabalu
# Items= 2
#
# https://www.omegawatches.com/store/country/malaysia/city/kuala-lumpur
# Items= 5
#
# https://www.omegawatches.com/store/country/malaysia/city/pahang
# Items= 1
#
# https://www.omegawatches.com/store/country/malaysia/city/penang
# Items= 1
#
# https://www.omegawatches.com/store/country/malaysia/city/selangor
# Items= 2
#
# https://www.omegawatches.com/store/country/malta/city/la-valletta
# Items= 1
#
# https://www.omegawatches.com/store/country/malta/city/luqa
# Items= 1
#
# https://www.omegawatches.com/store/country/malta/city/st-julians
# Items= 1
#
# https://www.omegawatches.com/store/country/mauritius/city/le-morne
# Items= 1
#
# https://www.omegawatches.com/store/country/mauritius/city/port-louis
# Items= 1
#
# https://www.omegawatches.com/store/country/mauritius/city/trou-d'eau-douce
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/boca-del-rio
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/cabo-san-lucas
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/cancun
# Items= 3
#
# https://www.omegawatches.com/store/country/mexico/city/ciudad-de-mexico
# Items= 7
#
# https://www.omegawatches.com/store/country/mexico/city/cozumel
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/culiacan
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/estado-de-mexico
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/guadalajara
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/merida
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/morelia
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/playa-del-carmen
# Items= 2
#
# https://www.omegawatches.com/store/country/mexico/city/puebla
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/queretaro
# Items= 1
#
# https://www.omegawatches.com/store/country/mexico/city/san-pedro-garza-garcia
# Items= 2
#
# https://www.omegawatches.com/store/country/monaco/city/monaco
# Items= 1
#
# https://www.omegawatches.com/store/country/mongolia/city/ulaanbaatar
# Items= 1
#
# https://www.omegawatches.com/store/country/montenegro/city/tivat
# Items= 1
#
# https://www.omegawatches.com/store/country/morocco/city/casablanca
# Items= 2
#
# https://www.omegawatches.com/store/country/myanmar/city/yangon
# Items= 2
#
# https://www.omegawatches.com/store/country/nepal/city/kathmandu
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/amsterdam
# Items= 4
#
# https://www.omegawatches.com/store/country/netherlands/city/breda
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/den-bosch
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/den-haag
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/eindhoven
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/enschede
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/groningen
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/haarlem
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/laren
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/maastricht
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/nijmegen
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/rijssen
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands/city/rotterdam
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/utrecht
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands/city/volendam
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands-antilles/city/harbor-point
# Items= 1
#
# https://www.omegawatches.com/store/country/netherlands-antilles/city/philipsburg
# Items= 2
#
# https://www.omegawatches.com/store/country/netherlands-antilles/city/willemstad
# Items= 1
#
# https://www.omegawatches.com/store/country/new-zealand/city/auckland
# Items= 2
#
# https://www.omegawatches.com/store/country/new-zealand/city/auckland-inter-airport
# Items= 1
#
# https://www.omegawatches.com/store/country/new-zealand/city/christchurch
# Items= 1
#
# https://www.omegawatches.com/store/country/new-zealand/city/wellington
# Items= 1
#
# https://www.omegawatches.com/store/country/nigeria/city/lagos
# Items= 1
#
# https://www.omegawatches.com/store/country/northern-mariana-islands/city/saipan
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/arendal
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/bergen
# Items= 2
#
# https://www.omegawatches.com/store/country/norway/city/gardermoen
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/haugesund
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/moss
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/oslo
# Items= 4
#
# https://www.omegawatches.com/store/country/norway/city/sandefjord
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/sandvika
# Items= 1
#
# https://www.omegawatches.com/store/country/norway/city/stavanger
# Items= 2
#
# https://www.omegawatches.com/store/country/norway/city/trondheim
# Items= 1
#
# https://www.omegawatches.com/store/country/oman/city/muscat
# Items= 5
#
# https://www.omegawatches.com/store/country/oman/city/salalah
# Items= 1
#
# https://www.omegawatches.com/store/country/pakistan/city/islamabad
# Items= 1
#
# https://www.omegawatches.com/store/country/pakistan/city/karachi
# Items= 2
#
# https://www.omegawatches.com/store/country/pakistan/city/lahore
# Items= 1
#
# https://www.omegawatches.com/store/country/panama/city/panama
# Items= 1
#
# https://www.omegawatches.com/store/country/papua-new-guinea/city/boroko
# Items= 1
#
# https://www.omegawatches.com/store/country/peru/city/lima
# Items= 2
#
# https://www.omegawatches.com/store/country/philippines/city/cebu-city
# Items= 1
#
# https://www.omegawatches.com/store/country/philippines/city/makati-city
# Items= 2
#
# https://www.omegawatches.com/store/country/philippines/city/mandaluyong-city
# Items= 2
#
# https://www.omegawatches.com/store/country/philippines/city/paranaque
# Items= 1
#
# https://www.omegawatches.com/store/country/philippines/city/taguig
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/gdansk
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/gdynia
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/katowice
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/krakow-cracow
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/lodz
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/lublin
# Items= 1
#
# https://www.omegawatches.com/store/country/poland/city/poznan
# Items= 2
#
# https://www.omegawatches.com/store/country/poland/city/warszawa-warsaw
# Items= 4
#
# https://www.omegawatches.com/store/country/poland/city/wroclaw
# Items= 1
#
# https://www.omegawatches.com/store/country/portugal/city/alcabideche
# Items= 1
#
# https://www.omegawatches.com/store/country/portugal/city/braga
# Items= 1
#
# https://www.omegawatches.com/store/country/portugal/city/faro
# Items= 1
#
# https://www.omegawatches.com/store/country/portugal/city/lisboa
# Items= 7
#
# https://www.omegawatches.com/store/country/portugal/city/oeiras
# Items= 1
#
# https://www.omegawatches.com/store/country/portugal/city/porto
# Items= 3
#
# https://www.omegawatches.com/store/country/portugal/city/senhora-da-hora
# Items= 1
#
# https://www.omegawatches.com/store/country/puerto-rico/city/isla-verde-carolina
# Items= 1
#
# https://www.omegawatches.com/store/country/puerto-rico/city/san-juan
# Items= 2
#
# https://www.omegawatches.com/store/country/qatar/city/doha
# Items= 9
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/busan
# Items= 3
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/daegu
# Items= 2
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/daejeon
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/goyang-si
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/gwangju
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/hanam-si
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/hwaseong-si
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/incheon
# Items= 2
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/jeju
# Items= 2
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/seoul
# Items= 17
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/sungnam-si
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/suwon
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/ulsan
# Items= 1
#
# https://www.omegawatches.com/store/country/republic-of-korea/city/yongin-si
# Items= 1
#
# https://www.omegawatches.com/store/country/reunion/city/saint-denis
# Items= 1
#
# https://www.omegawatches.com/store/country/romania/city/bucharest
# Items= 3
#
# https://www.omegawatches.com/store/country/russia/city/barnaul
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/blagoveschensk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/chelyabinsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/irkutsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/kaliningrad
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/kazan
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/khabarovsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/krasnodar
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/krasnoyarsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/makhachkala
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/moscow
# Items= 11
#
# https://www.omegawatches.com/store/country/russia/city/novorossiysk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/novosibirsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/omsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/penza
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/rostov-na-donu
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/samara
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/saratov
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/sochi
# Items= 2
#
# https://www.omegawatches.com/store/country/russia/city/st-petersburg
# Items= 3
#
# https://www.omegawatches.com/store/country/russia/city/tyumen
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/ufa
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/vladivostok
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/volgograd
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/voronezh
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/yakutsk
# Items= 1
#
# https://www.omegawatches.com/store/country/russia/city/yekaterinburg
# Items= 1
#
# https://www.omegawatches.com/store/country/saint-barthelemy/city/gustavia
# Items= 1
#
# https://www.omegawatches.com/store/country/saint-kitts-and-nevis/city/basseterre
# Items= 1
#
# https://www.omegawatches.com/store/country/saint-lucia/city/castries
# Items= 1
#
# https://www.omegawatches.com/store/country/saudi-arabia/city/al-khobar
# Items= 2
#
# https://www.omegawatches.com/store/country/saudi-arabia/city/jeddah
# Items= 3
#
# https://www.omegawatches.com/store/country/saudi-arabia/city/medinah
# Items= 1
#
# https://www.omegawatches.com/store/country/saudi-arabia/city/mekkah
# Items= 1
#
# https://www.omegawatches.com/store/country/saudi-arabia/city/riyadh
# Items= 3
#
# https://www.omegawatches.com/store/country/serbia/city/belgrade
# Items= 1
#
# https://www.omegawatches.com/store/country/singapore/city/singapore
# Items= 22
#
# https://www.omegawatches.com/store/country/slovakia/city/bratislava
# Items= 3
#
# https://www.omegawatches.com/store/country/slovakia/city/kosice
# Items= 1
#
# https://www.omegawatches.com/store/country/slovenia/city/ljubljana
# Items= 1
#
# https://www.omegawatches.com/store/country/slovenia/city/maribor
# Items= 1
#
# https://www.omegawatches.com/store/country/slovenia/city/portoroz
# Items= 1
#
# https://www.omegawatches.com/store/country/south-africa/city/cape-town
# Items= 3
#
# https://www.omegawatches.com/store/country/south-africa/city/gauteng
# Items= 1
#
# https://www.omegawatches.com/store/country/south-africa/city/johannesburg
# Items= 5
#
# https://www.omegawatches.com/store/country/south-africa/city/port-elizabeth
# Items= 1
#
# https://www.omegawatches.com/store/country/south-africa/city/pretoria
# Items= 2
#
# https://www.omegawatches.com/store/country/south-africa/city/umhlanga
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/a-coruna
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/albacete
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/alicante
# Items= 2
#
# https://www.omegawatches.com/store/country/spain/city/barcelona
# Items= 5
#
# https://www.omegawatches.com/store/country/spain/city/barcelona-sabadell
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/barcelona-vic
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/bilbao
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/cadiz
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/ceuta
# Items= 2
#
# https://www.omegawatches.com/store/country/spain/city/fuerteventura-antigua
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/fuerteventura-corralejo
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/fuerteventura-jandia
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/girona
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/girona-lloret-de-mar
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/gran-canaria-las-palmas
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/gran-canaria-playa-meloneras
# Items= 3
#
# https://www.omegawatches.com/store/country/spain/city/ibiza
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/lanzarote-costa-teguise
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/lanzarote-playa-blanca-yaiza
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/las-palmas
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/madrid
# Items= 7
#
# https://www.omegawatches.com/store/country/spain/city/madrid-pozuelo-de-alarcon
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/malaga
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/mallorca-palma
# Items= 2
#
# https://www.omegawatches.com/store/country/spain/city/murcia
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/oviedo
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/pamplona
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/puerto-banus
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/salamanca
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/san-sebastian
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/santander
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/sevilla
# Items= 2
#
# https://www.omegawatches.com/store/country/spain/city/tarragona-reus
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/tenerife-costa-adeje
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/tenerife-playa-de-las-americas
# Items= 2
#
# https://www.omegawatches.com/store/country/spain/city/tenerife-santa-cruz
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/valencia
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/valencia-gandia
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/valladolid
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/vigo
# Items= 1
#
# https://www.omegawatches.com/store/country/spain/city/zaragoza
# Items= 1
#
# https://www.omegawatches.com/store/country/sri-lanka/city/colombo-02
# Items= 1
#
# https://www.omegawatches.com/store/country/sri-lanka/city/colombo-03
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/goteborg
# Items= 2
#
# https://www.omegawatches.com/store/country/sweden/city/halmstad
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/helsingborg-odakra
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/jonkoping
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/kalmar
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/malmo
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/stockholm
# Items= 4
#
# https://www.omegawatches.com/store/country/sweden/city/sundbyberg
# Items= 1
#
# https://www.omegawatches.com/store/country/sweden/city/uppsala
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/arosa
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/ascona
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/baden
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/basel
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/bern
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/biel-bienne
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/brugg-ag
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/burgenstock
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/chur
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/crans-montana
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/davos
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/engelberg
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/geneva
# Items= 6
#
# https://www.omegawatches.com/store/country/switzerland/city/glattzentrum
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/grindelwald
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/interlaken
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/klosters
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/kriens
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/lausanne
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/locarno
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/lugano
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/luzern
# Items= 3
#
# https://www.omegawatches.com/store/country/switzerland/city/montreux
# Items= 2
#
# https://www.omegawatches.com/store/country/switzerland/city/neuchatel
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/olten
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/reinach
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/samnaun
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/schaffhausen
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/solothurn
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/st-gallen
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/st-moritz
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/thun
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/vevey
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/winterthur
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/zermatt
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/zug
# Items= 1
#
# https://www.omegawatches.com/store/country/switzerland/city/zurich
# Items= 4
#
# https://www.omegawatches.com/store/country/switzerland/city/zurich-airport
# Items= 3
#
# https://www.omegawatches.com/store/country/syria/city/damas
# Items= 1
#
# https://www.omegawatches.com/store/country/taiwan-region/city/hsinchu
# Items= 2
#
# https://www.omegawatches.com/store/country/taiwan-region/city/kaohsiung
# Items= 3
#
# https://www.omegawatches.com/store/country/taiwan-region/city/keelung
# Items= 1
#
# https://www.omegawatches.com/store/country/taiwan-region/city/kinmen
# Items= 1
#
# https://www.omegawatches.com/store/country/taiwan-region/city/new-taipei-city
# Items= 2
#
# https://www.omegawatches.com/store/country/taiwan-region/city/taichung
# Items= 3
#
# https://www.omegawatches.com/store/country/taiwan-region/city/tainan
# Items= 2
#
# https://www.omegawatches.com/store/country/taiwan-region/city/taipei
# Items= 10
#
# https://www.omegawatches.com/store/country/taiwan-region/city/taoyuan
# Items= 3
#
# https://www.omegawatches.com/store/country/tajikistan/city/dushanbe
# Items= 1
#
# https://www.omegawatches.com/store/country/tanzania/city/dar-es-salaam
# Items= 1
#
# https://www.omegawatches.com/store/country/thailand/city/bangkok
# Items= 8
#
# https://www.omegawatches.com/store/country/thailand/city/pattaya
# Items= 1
#
# https://www.omegawatches.com/store/country/thailand/city/phuket
# Items= 4
#
# https://www.omegawatches.com/store/country/thailand/city/samutprakarn
# Items= 2
#
# https://www.omegawatches.com/store/country/tunisia/city/sidi-daoud
# Items= 1
#
# https://www.omegawatches.com/store/country/tunisia/city/tunis
# Items= 1
#
# https://www.omegawatches.com/store/country/turkey/city/ankara
# Items= 2
#
# https://www.omegawatches.com/store/country/turkey/city/antalya
# Items= 6
#
# https://www.omegawatches.com/store/country/turkey/city/bursa
# Items= 1
#
# https://www.omegawatches.com/store/country/turkey/city/istanbul
# Items= 6
#
# https://www.omegawatches.com/store/country/turkey/city/izmir
# Items= 2
#
# https://www.omegawatches.com/store/country/turkey/city/mugla
# Items= 1
#
# https://www.omegawatches.com/store/country/ukraine/city/dnepropetrovsk
# Items= 1
#
# https://www.omegawatches.com/store/country/ukraine/city/dnipro
# Items= 1
#
# https://www.omegawatches.com/store/country/ukraine/city/kharkov
# Items= 1
#
# https://www.omegawatches.com/store/country/ukraine/city/kiev
# Items= 2
#
# https://www.omegawatches.com/store/country/ukraine/city/lwiw
# Items= 1
#
# https://www.omegawatches.com/store/country/ukraine/city/zaporozhie
# Items= 1
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/abu-dhabi
# Items= 9
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/ajman
# Items= 1
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/al-ain
# Items= 3
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/dubai
# Items= 26
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/fujairah
# Items= 2
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/ras-al-khaimah
# Items= 2
#
# https://www.omegawatches.com/store/country/united-arab-emirates/city/sharjah
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/aberdeen
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/ayr
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/banbury
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/basingstoke
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bath
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bedford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/belfast
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/birmingham
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bishop-stortford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/blackpool
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bournemouth
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/brighton
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bristol
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bromley
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/bury-st-edmunds
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/cambridge
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/canterbury
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/cardiff
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/chelmsford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/cheltenham
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/chichester
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/colchester
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/crewe
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/croydon
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/derby
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/dudley
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/dundee
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/edinburgh
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/essex
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/exeter
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/gateshead
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/gatwick-airport
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/glasgow
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/greenhithe
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/guernsey
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/guildford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/halifax
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/hampshire
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/harrogate
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/hereford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/horsham
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/hull
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/ilkley
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/inverness
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/ipswich
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/jersey
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/kingston-upon-thames
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/lancaster
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/leamington-spa
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/leeds
# Items= 4
#
# https://www.omegawatches.com/store/country/united-kingdom/city/leicester
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/liverpool
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/london
# Items= 17
#
# https://www.omegawatches.com/store/country/united-kingdom/city/london-heathrow
# Items= 4
#
# https://www.omegawatches.com/store/country/united-kingdom/city/maidstone
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/manchester
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/middlesbrough
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/milton-keynes
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/newbury
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/newcastle-under-lyme
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/newcastle-upon-tyne
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/northampton
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/norwich
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/nottingham
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/nuneaton
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/oxford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/perth
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/peterborough
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/plymouth
# Items= 2
#
# https://www.omegawatches.com/store/country/united-kingdom/city/portsmouth
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/preston
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/reading
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/sheffield
# Items= 3
#
# https://www.omegawatches.com/store/country/united-kingdom/city/solihull
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/southampton
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/stoke-on-trent
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/stratford-upon-avon
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/swansea
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/truro
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/tunbridge-wells
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/watford
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/windsor
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/witney
# Items= 1
#
# https://www.omegawatches.com/store/country/united-kingdom/city/york
# Items= 2
#
# https://www.omegawatches.com/store/country/united-states-virgin-islands/city/st-john
# Items= 1
#
# https://www.omegawatches.com/store/country/united-states-virgin-islands/city/st-thomas
# Items= 7
#
# https://www.omegawatches.com/store/country/uruguay/city/punta-del-este
# Items= 1
#
# https://www.omegawatches.com/store/country/uzbekistan/city/tashkent
# Items= 1
#
# https://www.omegawatches.com/store/country/vanuatu/city/port-vila
# Items= 1
#
# https://www.omegawatches.com/store/country/vietnam/city/ho-chi-minh-city
# Items= 2
#
# https://www.omegawatches.com/store/country/yemen/city/aden
# Items= 3
#
# https://www.omegawatches.com/store/country/yemen/city/sana'a
# Items= 3
#
# https://www.omegawatches.com/store/country/yemen/city/ta'izz
# Items= 1
#
# https://www.omegawatches.com/store/country/yemen/city/taiz
# Items= 2
#
# total stores: 1416

# %%
len(df)
# Out:
# 1416

# %%
df
# Out:
#                                 store_name  \
# 0     GOTTFRIED Bab Ezzouar - MS DIFFUSION
# 1     GOTTFRIED Dely Brahim - MS DIFFUSION
# 2            GOTTFRIED Golf - MS DIFFUSION
# 3      GOTTFRIED Sidi Yahia - MS DIFFUSION
# 4        GOTTFRIED Es Senia - MS DIFFUSION
# ...                                    ...
# 1413            Swiss Watches Union Agency
# 1414            Swiss Watches Union Agency
# 1415            Swiss Watches Union Agency
# 1416            Swiss Watches Union Agency
# 1417            Swiss Watches Union Agency
#
#                                  store_address1      store_address2  \
# 0                 Centre Commercial Bab Ezzouar          DZ - Alger
# 1             Bois des Cares ndeg2, Dely Brahim          DZ - Alger
# 2              2, Rue Shakespeare - El Mouradia          DZ - Alger
# 3           Chemin Sidi Yahia ndeg6, Sidi Yahia          DZ - Alger
# 4     Centre Commercial El Kerma, 52 showroom B                Oran
# ...                                         ...                 ...
# 1413                        Sana'a Trade Center          Algiers St
# 1414                        Sana'a Trade Center         Algiers St.
# 1415                   Arafat Commercial Market     26 September St
# 1416                   Arafat Commercial Market    26 September St.
# 1417   Mr. Abdul Rahman N. M. Al-Maamari & Sons  26 September Stree
#
#      store_address3 store_address4 store_address5 store_address6  \
# 0           Algeria           None           None           None
# 1           Algeria           None           None           None
# 2           Algeria           None           None           None
# 3           Algeria           None           None           None
# 4           Algeria           None           None           None
# ...             ...            ...            ...            ...
# 1413         Sana'a          Yemen           None           None
# 1414         Sana'a          Yemen           None           None
# 1415         Ta'izz          Yemen           None           None
# 1416           Taiz          Yemen           None           None
# 1417  P.O. Box 5384           Taiz          Yemen           None
#
#      store_address7  brand  is_partner
# 0              None  Omega           1
# 1              None  Omega           1
# 2              None  Omega           1
# 3              None  Omega           1
# 4              None  Omega           1
# ...             ...    ...         ...
# 1413           None  Omega           1
# 1414           None  Omega           1
# 1415           None  Omega           1
# 1416           None  Omega           1
# 1417           None  Omega           1
#
# [1416 rows x 10 columns]

# %%
brand = 'OMEGA'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/OMEGA_092021.xlsx

# %% [markdown]
# # Hublot

# %%
config = config_all['HUBLOT']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
items_boutique = get_items(driver, config["items_boutique"])
print("Number of items_boutique:",len(items_boutique))

for item in items_boutique:
    rows_list.append({
            'store_name': get_value(item,config,'store_name'),
            'store_address': get_value(item,config,'store_address'),
            'brand': "Hublot",
            'is_partner': '0'
        })

items_retailer = get_items(driver, config["items_retailer"])
print("Number of items_retailer:",len(items_retailer))

for item in items_retailer:
    rows_list.append({
            'store_name': get_value(item,config,'store_name'),
            'store_address': get_value(item,config,'store_address'),
            'brand': "Hublot",
            'is_partner': '1'
        })       
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# Number of items_boutique: 135
# Number of items_retailer: 628
# total stores: 751

# %%
len(df)
# Out:
# 751

# %%
brand = 'HUBLOT'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/HUBLOT_092021.xlsx

# %% [markdown]
# # TUDOR

# %%
config = config_all['TUDOR']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Dezoom on map to get as much stores points as possible
# - Move across the map
# - Don't forget Hawaii and Northern Mariana Islands

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    store_name1 = get_value(item, config, 'store_name1')
    store_name2 = get_value(item, config, 'store_name2')

    store_address1 = get_value(item, config, 'store_address1')
    store_address2 = get_value(item, config, 'store_address2')
    store_address3 = get_value(item, config, 'store_address3')
    store_address4 = get_value(item, config, 'store_address4')
    store_address5 = get_value(item, config, 'store_address5')
    store_address6 = get_value(item, config, 'store_address6')
    store_address7 = get_value(item, config, 'store_address7')
    
    store_partner = get_value(item, config, 'store_partner')
        
    rows_list.append({
        'store_name1': store_name1,
        'store_name2': store_name2,
        'store_address1': store_address1,
        'store_address2': store_address2,
        'store_address3': store_address3,
        'store_address4': store_address4,
        'store_address5': store_address5,
        'store_address6': store_address6,
        'store_address7': store_address7,
        'store_partner': store_partner,
        'brand': 'Tudor'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 2
# total stores: 1730

# %%
df['is_partner'] = df['store_partner'].apply(lambda x : extract_partner(x, 'Tudor'))

# %%
df
# Out:
#                             store_name1 store_name2  \
# 0                     ‭Alain Joaillier‬        None
# 1                     ‭Alain Joaillier‬        None
# 2     ‭Anshindo Horloger La Paix Paris‬        None
# 3          ‭Antoine de Macedo Horloger‬        None
# 4                               ‭Arije‬        None
# ...                                 ...         ...
# 7433                   ‭The Royal Shop‬        None
# 7495       ‭Casa Banchero Jockey Plaza‬        None
# 7496         ‭Casa Banchero Miraflores‬        None
# 7504              ‭RELÓGIOS ROLEX LTDA‬        None
# 7506             ‭ROLEX ARGENTINA S.A.‬        None
#
#                                          store_address1  \
# 0                                      35 Rue du Temple
# 1                                       27 Rue Gambetta
# 2                                      8 Rue de la Paix
# 3                           201 Boulevard Saint Germain
# 4                                 50 Rue Pierre Charron
# ...                                                 ...
# 7433                    The Royal Shop, 32 Broad Street
# 7495                        Av. La Paz 1010, Miraflores
# 7496  Centro Comercial Jockey Plaza - Av. Javier Pra...
# 7504                             Avenida Paulista, 2006
# 7506                                      Suipacha 1111
#
#                store_address2         store_address3 store_address4  \
# 0           17000 La Rochelle      Charente Maritime         France
# 1     Royan Charente Maritime                  17200         France
# 2                 75002 Paris                  Paris         France
# 3                 Paris Paris                  75006         France
# 4                 75008 Paris                  Paris         France
# ...                       ...                    ...            ...
# 7433         Bridgetown 11000          Saint Michael       Barbados
# 7495                     Lima            Lima 150122           Peru
# 7496                Lima Lima                  15023           Peru
# 7504                14° andar    01310-926 Sao Paulo         Brazil
# 7506                  Piso 24  C1008AAW Buenos Aires      Argentina
#
#      store_address5 store_address6 store_address7  \
# 0              None           None           None
# 1              None           None           None
# 2              None           None           None
# 3              None           None           None
# 4              None           None           None
# ...             ...            ...            ...
# 7433           None           None           None
# 7495           None           None           None
# 7496           None           None           None
# 7504           None           None           None
# 7506           None           None           None
#
#                       store_partner  brand  is_partner
# 0     Official TUDOR Watch retailer  Tudor           1
# 1     Official TUDOR Watch retailer  Tudor           1
# 2     Official TUDOR Watch retailer  Tudor           1
# 3     Official TUDOR Watch retailer  Tudor           1
# 4     Official TUDOR Watch retailer  Tudor           1
# ...                             ...    ...         ...
# 7433  Official TUDOR Watch retailer  Tudor           1
# 7495  Official TUDOR Watch retailer  Tudor           1
# 7496  Official TUDOR Watch retailer  Tudor           1
# 7504                Tudor affiliate  Tudor           1
# 7506                Tudor affiliate  Tudor           1
#
# [1730 rows x 12 columns]

# %%
brand = 'TUDOR'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/TUDOR_092021.xlsx

# %% [markdown]
# # ULYSSE NARDIN

# %%
config = config_all['ULYSSE NARDIN']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Filter Retailers
# - Dezoom max on the map

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    
    store_name = get_value(item, config, 'store_name')
    store_address1 = get_value(item, config, 'store_address1')
    store_address2 = get_value(item, config, 'store_address2')
    store_address3 = get_value(item, config, 'store_address3')
    country = get_value(item, config, 'country')
        
    rows_list.append({
        'store_name': store_name,
        'store_address1': store_address1,
        'store_address2': store_address2,
        'store_address3': store_address3,
        'country': country,
        'brand': 'Ulysse Nardin',        
        'is_partner': '1'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 396
# total stores: 395

# %%
df.head()
# Out:
#                                 store_name         store_address1  \
# 0                       Tiempo Global S.A.  Plaza Colonia, Escazù
# 1  UHRSACHEN (MAEGLI – TICK DIFFERENT AG))           Kramgasse 19
# 2                      LES AMBASSADEURS SA        Rue du Rhône 62
# 3                      Les Ambassadeurs SA            Via Nassa 5
# 4                      LES AMBASSADEURS AG      Bahnhofstrasse 64
#
#   store_address2 store_address3      country          brand is_partner
# 0           None       SAN JOSE   Costa Rica  Ulysse Nardin          1
# 1           3011           Bern  Switzerland  Ulysse Nardin          1
# 2           1204         Genève  Switzerland  Ulysse Nardin          1
# 3           6900         Lugano  Switzerland  Ulysse Nardin          1
# 4           8001        Zuerich  Switzerland  Ulysse Nardin          1

# %%
brand = 'ULYSSE_NARDIN'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/ULYSSE_NARDIN_092021.xlsx

# %% [markdown]
# # GIRARD PERREGAUX

# %%
config = config_all['GIRARD PERREGAUX']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %% [markdown]
# - Filter Retailers
# - Dezoom max on the map and move across to collect stores

# %%
items = get_items(driver, config["items"])
print('boutiques:', len(items))

for item in items:
    
    store_name = get_value(item, config, 'store_name')
    store_address1 = get_value(item, config, 'store_address1')
    store_address2 = get_value(item, config, 'store_address2')
    store_address3 = get_value(item, config, 'store_address3')
        
    rows_list.append({
        'store_name': store_name,
        'store_address1': store_address1,
        'store_address2': store_address2,
        'store_address3': store_address3,
        'brand': 'Girard Perregaux',        
        'is_partner': '1'
    })
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# boutiques: 0
# total stores: 290

# %%
df.head()
# Out:
#              store_name            store_address1   store_address2  \
# 0          JOYERIA JAEL              Compostela 8   15004 A Coruña
# 1       JOYERÍA ABRINES                  Tetuan 1    41001 Sevilla
# 2        Massimo Bianco       Calle del Teatro 38   03001 Alicante
# 3  Miguel Munoz Joyeros  Calle Reyes Catolicos 29    18001 Granada
# 4     Rabat - Barcelona      Passeig de Gracia 94  08008 Barcelona
#
#   store_address3             brand is_partner
# 0          Spain  Girard Perregaux          1
# 1          Spain  Girard Perregaux          1
# 2          Spain  Girard Perregaux          1
# 3          Spain  Girard Perregaux          1
# 4          Spain  Girard Perregaux          1

# %%
brand = 'GIRARD_PERREGAUX'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/GIRARD_PERREGAUX_092021.xlsx

# %% [markdown]
# # LONGINES

# %%
config = config_all['LONGINES']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = get_items(driver, config["country_code"])
print("Number of countries=",len(country_codes))

for idx, country_code in enumerate(country_codes):
    print(country_code)
    url_country = "https://www.longines.com/retailers/" + country_code.lower()
    
    driver.get(url_country)
    time.sleep(3)

    country_region_codes = get_items(driver,config["country_region_code"])
    for country_region_code in country_region_codes:
        #The first item is "Choose a Region". We pass it
        if country_region_code == "0":
            continue
        print(country_region_code)
        url_country_region = "https://www.longines.com/retailers/" + country_region_code.lower()
        
        driver.get(url_country_region)
        time.sleep(3)   
        
        country_region_city_codes = get_items(driver,config["country_region_city_code"])
        for country_region_city_code in country_region_city_codes:
            #The first item is "Choose a City". We pass it
            if country_region_city_code == "0":
                continue            
            print(country_region_city_code)
            url_country_region_city = "https://www.longines.com/retailers/" + country_region_city_code.lower()

            driver.get(url_country_region_city)
            time.sleep(3)           
        
            items_boutique = get_items(driver, config["items_boutique"])
            print("Number of items_boutique:",len(items_boutique))

            for item in items_boutique:
                rows_list.append({
                        'store_name1': get_value(item,config,'store_name1'),
                        'store_name2': get_value(item,config,'store_name2'),
                        'store_address1': get_value(item,config,'store_address1'),
                        'store_address2': get_value(item,config,'store_address2'),
                        'brand': "Longines",
                        'is_partner': '0'
                    })

            items_retailer = get_items(driver, config["items_retailer"])
            print("Number of items_retailer:",len(items_retailer))

            for item in items_retailer:
                rows_list.append({
                        'store_name1': get_value(item,config,'store_name1'),
                        'store_name2': get_value(item,config,'store_name2'),
                        'store_address1': get_value(item,config,'store_address1'),
                        'store_address2': get_value(item,config,'store_address2'),
                        'brand': "Longines",
                        'is_partner': '1'
                    })                
                
            items_distribu = get_items(driver, config["items_distribu"])
            print("Number of items_distribu:",len(items_distribu))

            for item in items_distribu:
                rows_list.append({
                        'store_name1': get_value(item,config,'store_name1'),
                        'store_name2': get_value(item,config,'store_name2'),
                        'store_address1': get_value(item,config,'store_address1'),
                        'store_address2': get_value(item,config,'store_address2'),
                        'brand': "Longines",
                        'is_partner': '1'
                    })                    
                
                
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# Number of countries= 140
# af
# af/kabul
# af/kabul/kabul
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# al
# al/tirana
# al/tirana/tirana
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# dz
# dz/algiers
# dz/algiers/alger
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 1
# dz/oran
# dz/oran/oran
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ad
# ad/andorralavella
# ad/andorralavella/andorralavella
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# ao
# ao/provincedebenguela
# ao/provincedebenguela/benguela
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# ao/provincedehuambo
# ao/provincedehuambo/huambo
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# ao/provincedehuila
# ao/provincedehuila/lubango
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# ao/provincedeluanda
# ao/provincedeluanda/luanda
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 0
# ag
# ag/antigua
# ag/antigua/stjohns
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# ar
# ar/autonomouscityofbuenosaires
# ar/autonomouscityofbuenosaires/buenosaires
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ar/autonomouscityofbuenosaires/ciudadautdebsas
# Number of items_boutique: 0
# Number of items_retailer: 13
# Number of items_distribu: 1
# ar/buenosairesprovince
# ar/buenosairesprovince/bahiablanca
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/buenosairesprovince/citybell
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/buenosairesprovince/laplata
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ar/buenosairesprovince/mardelplata
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/buenosairesprovince/martinez
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/buenosairesprovince/quilmes
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/buenosairesprovince/sanisidro
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/chacoprovince
# ar/chacoprovince/resistencia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/corrientesprovince
# ar/corrientesprovince/corrientes
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/lapampaprovince
# ar/lapampaprovince/generalpico
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/lapampaprovince/santarosa
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/mendozaprovince
# ar/mendozaprovince/godoycruz
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/neuquen
# ar/neuquen/neuquen
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/provinciadecordoba
# ar/provinciadecordoba/cordoba
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ar/santafeprovince
# ar/santafeprovince/rosario
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ar/santafeprovince/santafe
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/santiagodelesteroprovince
# ar/santiagodelesteroprovince/santiagodelestero
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ar/tucuman
# ar/tucuman/tucuman
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# am
# am/yerevan
# am/yerevan/yerevan
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# aw
# aw/noord
# aw/noord/noord
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# aw/oranjestad
# aw/oranjestad/oranjestad
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# aw/palmbeach
# aw/palmbeach/palmbeacharuba
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# au
# au/australiancapitalterritory
# au/australiancapitalterritory/canberra
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# au/newsouthwales
# au/newsouthwales/chatswood
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# au/newsouthwales/sydney
# Number of items_boutique: 2
# Number of items_retailer: 12
# Number of items_distribu: 0
# au/queensland
# au/queensland/brisbane
# Number of items_boutique: 0
# Number of items_retailer: 9
# Number of items_distribu: 0
# au/queensland/cairns
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 0
# au/queensland/goldcoast
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# au/queensland/northlakes
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# au/southaustralia
# au/southaustralia/adelaide
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 0
# au/victoria
# au/victoria/melbourne
# Number of items_boutique: 1
# Number of items_retailer: 18
# Number of items_distribu: 0
# au/westernaustralia
# au/westernaustralia/perth
# Number of items_boutique: 0
# Number of items_retailer: 9
# Number of items_distribu: 0
# at
# at/burgenland
# at/burgenland/badsauerbrunn
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/burgenland/eisenstadt
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/burgenland/grosspetersdorf
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/burgenland/neusiedlamsee
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/burgenland/parndorf
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/carinthia
# at/carinthia/klagenfurt
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 0
# at/carinthia/spittaldrau
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/carinthia/velden
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/carinthia/villach
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/loweraustria
# at/loweraustria/amstetten
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/loweraustria/baden
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/loweraustria/krems
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/loweraustria/stpolten
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/loweraustria/vosendorf
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# at/niederosterreich
# at/niederosterreich/himberg
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/niederosterreich/klosterneuburg
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/niederosterreich/modling
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/niederosterreich/nitzing
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/niederosterreich/obergrafendorf
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/niederosterreich/schwechat
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/salzburg
# at/salzburg/henndorfamwallersee
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/salzburg/salzburg
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 0
# at/salzburg/strasswalchen
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/styriaaut
# at/styriaaut/bruckmur
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/styriaaut/graz
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/styriaaut/hartberg
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/styriaaut/leoben
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/styriaaut/lieboch
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/tyrol
# at/tyrol/innsbruck
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# at/tyrol/ischgl
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/tyrol/jenbach
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/tyrol/kitzbuhel
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# at/tyrol/riedimoberinntal
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/tyrol/seefeld
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/tyrol/telfs
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/tyrol/worgl
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/upperaustria
# at/upperaustria/enns
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/upperaustria/linz
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# at/upperaustria/pasching
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/upperaustria/riedinnkreis
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/upperaustria/wels
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/upperaustria/wildenhag
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/vienna
# at/vienna/wien
# Number of items_boutique: 0
# Number of items_retailer: 17
# Number of items_distribu: 0
# at/vorarlberg
# at/vorarlberg/bludenz
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/vorarlberg/bregenz
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/vorarlberg/dornbirn
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/vorarlberg/feldkirch
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/vorarlberg/gotzis
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# at/vorarlberg/hohenems
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# at/vorarlberg/riezlernkleinwalsertal
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# az
# az/baku
# az/baku/baku
# Number of items_boutique: 1
# Number of items_retailer: 6
# Number of items_distribu: 1
# az/ganja
# az/ganja/ganja
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# az/shaki
# az/shaki/sheki
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bs
# bs/newprovidence
# bs/newprovidence/nassau
# Number of items_boutique: 1
# Number of items_retailer: 0
# Number of items_distribu: 0
# bh
# bh/bahrein
# bh/bahrein/manama
# Number of items_boutique: 1
# Number of items_retailer: 5
# Number of items_distribu: 0
# bh/muharraqgovernorate
# bh/muharraqgovernorate/muharraq
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# bd
# bd/chittagongdivision
# bd/chittagongdivision/chittagong
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bd/dhakadivision
# bd/dhakadivision/dhaka
# Number of items_boutique: 0
# Number of items_retailer: 7
# Number of items_distribu: 1
# bb
# bb/saintmichael
# bb/saintmichael/bridgetown
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 0
# by
# by/minsk
# by/minsk/minsk
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 0
# be
# be/antwerp
# be/antwerp/antwerpen
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# be/antwerp/geel
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/antwerp/heistopdenberg
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/antwerp/mortsel
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/antwerp/turnhout
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/antwerp/wijnegem
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/antwerp/zwijndrecht
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# be/brussels
# be/brussels/brussels
# Number of items_boutique: 0
# Number of items_retailer: 8
# Number of items_distribu: 1
# be/eastflanders
# be/eastflanders/aalst
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/eastflanders/evergem
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# be/eastflanders/gent
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/eastflanders/ninove
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/eastflanders/sintniklaas
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/eastflanders/temse
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/flemishbrabant
# be/flemishbrabant/halle
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/flemishbrabant/leuven
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/flemishbrabant/rixensart
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# be/flemishbrabant/tervuren
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/flemishbrabant/zaventem
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/hainaut
# be/hainaut/charleroi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/hainaut/enghien
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/hainaut/monscuesmes
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/hainaut/mouscron
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/hainaut/tournai
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/liege
# be/liege/liege
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/liege/montegnee
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# be/liege/verviers
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/limburg
# be/limburg/hasselt
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# be/limburg/sinttruiden
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/luxembourg
# be/luxembourg/arlon
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/provinceofnamur
# be/provinceofnamur/namur
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/walloonbrabant
# be/walloonbrabant/louvainlaneuve
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/walloonbrabant/waterloo
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/westflanders
# be/westflanders/brugge
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/westflanders/knokke
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# be/westflanders/kortrijk
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/westflanders/oostkamp
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# be/westflanders/waregem
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bz
# bz/belize
# bz/belize/corozal
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bo
# bo/santacruz
# bo/santacruz/santacruz
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ba
# ba/banjaluka
# ba/banjaluka/banjaluka
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ba/kantonsarajevo
# ba/kantonsarajevo/sarajevo
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# ba/kantonsarajevo/tuzla
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# br
# br/riodejaneiro
# br/riodejaneiro/riodejaneiro
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# br/saopaulo
# br/saopaulo/saopaulo
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 0
# vg
# vg/tortola
# vg/tortola/tortola
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# bg
# bg/burgas
# bg/burgas/burgas
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bg/plovdiv
# bg/plovdiv/plovdiv
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# bg/sofia
# bg/sofia/sofia
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# bg/varnamunicipality
# bg/varnamunicipality/varna
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# kh
# kh/banteaymeanchey
# kh/banteaymeanchey/poipet
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# kh/batdambang
# kh/batdambang/battambongprovince
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# kh/kompongchamprovince
# kh/kompongchamprovince/kompongchamprovince
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# kh/phnompenh
# kh/phnompenh/phnompenh
# Number of items_boutique: 1
# Number of items_retailer: 6
# Number of items_distribu: 0
# kh/siemreap
# kh/siemreap/siemreap
# Number of items_boutique: 1
# Number of items_retailer: 3
# Number of items_distribu: 0
# kh/sihanoukvilleprovince
# kh/sihanoukvilleprovince/kampongsomprovince
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# ca
# ca/alberta
# ca/alberta/calgary
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 1
# ca/alberta/edmonton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/alberta/rockyview
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/britishcolumbia
# ca/britishcolumbia/burnaby
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/britishcolumbia/coquitlam
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ca/britishcolumbia/langley
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/britishcolumbia/richmond
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# ca/britishcolumbia/surrey
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ca/britishcolumbia/vancouver
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 1
# ca/britishcolumbia/victoria
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# ca/britishcolumbia/westvancouver
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# ca/manitoba
# ca/manitoba/winnipeg
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ca/ontario
# ca/ontario/brampton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/cambridge
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/etobicoke
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ca/ontario/hamilton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/markham
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# ca/ontario/mississauga
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# ca/ontario/oakville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/oshawa
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/ottawa
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/queenston
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/rideau
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/stcatharines
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/toronto
# Number of items_boutique: 0
# Number of items_retailer: 10
# Number of items_distribu: 1
# ca/ontario/vaughan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/waterloo
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/whitby
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/windsor
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/ontario/woodbridge
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec
# ca/quebec/brossard
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec/lacolle
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec/lasalle
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec/laval
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec/montreal
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 1
# ca/quebec/pointeclaire
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/quebec/quebeccity
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# ca/quebec/stbruno
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ca/saskatchewan
# ca/saskatchewan/saskatoon
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ky
# ky/georgetown
# ky/georgetown/georgetown
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 0
# cl
# cl/antofagastaregion
# cl/antofagastaregion/antofagasta
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/antofagastaregion/calama
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/atacamaregion
# cl/atacamaregion/copiapo
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/biobioregion
# cl/biobioregion/concepcion
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# cl/biobioregion/losangeles
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/biobioregion/talcahuano
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/coquimboregion
# cl/coquimboregion/laserena
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/laaraucania
# cl/laaraucania/temuco
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/loslagosregion
# cl/loslagosregion/osorno
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/loslagosregion/puertomontt
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/losriosregion
# cl/losriosregion/valdivia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/magallanesylaantarticachilenaregion
# cl/magallanesylaantarticachilenaregion/puntaarenas
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# cl/mauleregion
# cl/mauleregion/talca
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# cl/ohigginsregion
# cl/ohigginsregion/rancagua
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/santiagometropolitanregion
# cl/santiagometropolitanregion/santiago
# Number of items_boutique: 1
# Number of items_retailer: 18
# Number of items_distribu: 1
# cl/tarapacaregion
# cl/tarapacaregion/iquique
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/valparaiso
# cl/valparaiso/valparaiso
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cl/valparaiso/vinadelmar
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cn
# cn/anhui
# cn/anhui/anqing
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/bengbu
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/anhui/chuzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/fuyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/hefei
# Number of items_boutique: 2
# Number of items_retailer: 6
# Number of items_distribu: 7
# cn/anhui/huaibei
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/huainan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/liuan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/maanshan
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/anhui/tongling
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/anhui/wuhu
# Number of items_boutique: 1
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/anhui/xuancheng
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/beijing
# cn/beijing/beijing
# Number of items_boutique: 11
# Number of items_retailer: 17
# Number of items_distribu: 7
# cn/chongqing
# cn/chongqing/chongqing
# Number of items_boutique: 7
# Number of items_retailer: 12
# Number of items_distribu: 7
# cn/fujian
# cn/fujian/fuzhou
# Number of items_boutique: 1
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/fujian/jinjiang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/fujian/quanzhou
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/fujian/xiamen
# Number of items_boutique: 1
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/gansu
# cn/gansu/lanzhou
# Number of items_boutique: 1
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/guangdong
# cn/guangdong/dongguan
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/guangdong/foshan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/guangdong/guangzhou
# Number of items_boutique: 3
# Number of items_retailer: 7
# Number of items_distribu: 7
# cn/guangdong/huizhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/guangdong/shantou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/guangdong/shenzhen
# Number of items_boutique: 3
# Number of items_retailer: 9
# Number of items_distribu: 7
# cn/guangdong/zhuhai
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/guangxi
# cn/guangxi/guilin
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/guangxi/liuzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/guangxi/nanning
# Number of items_boutique: 2
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/guizhou
# cn/guizhou/guiyang
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 7
# cn/guizhou/zunyi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hainan
# cn/hainan/haikou
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/hainan/sanya
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei
# cn/hebei/baoding
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hebei/cangzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei/chengde
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei/handan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei/hengshui
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei/langfang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hebei/qinghuangdao
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hebei/shijiazhuang
# Number of items_boutique: 2
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hebei/tangshan
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hebei/xingtai
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang
# cn/heilongjiang/daqing
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/harbin
# Number of items_boutique: 2
# Number of items_retailer: 8
# Number of items_distribu: 7
# cn/heilongjiang/hegang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/heihe
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/jiamusi
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/heilongjiang/jixi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/mudanjiang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/qiqihaer
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/heilongjiang/qitaihe
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/heilongjiang/suihua
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan
# cn/henan/anyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/jiaozuo
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/kaifeng
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/luoyang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/henan/nanyang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/henan/pingdingshan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/puyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/shangqiu
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/xingxiang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/xinyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/xuchang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/zhengzhou
# Number of items_boutique: 3
# Number of items_retailer: 6
# Number of items_distribu: 7
# cn/henan/zhoukou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/henan/zhumadian
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hubei
# cn/hubei/huangshi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hubei/shiyan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hubei/wuhan
# Number of items_boutique: 3
# Number of items_retailer: 9
# Number of items_distribu: 7
# cn/hubei/xiangyang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hubei/xiantao
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hubei/yichang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/hunan
# cn/hunan/changde
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hunan/changsha
# Number of items_boutique: 2
# Number of items_retailer: 6
# Number of items_distribu: 7
# cn/hunan/chenzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hunan/hengyang
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/hunan/shaoyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hunan/xiangtan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hunan/yueyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/hunan/zhuzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/innermongolia
# cn/innermongolia/baotou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/innermongolia/erdos
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/innermongolia/hailaer
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/innermongolia/huhehaote
# Number of items_boutique: 2
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu
# cn/jiangsu/changshu
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/changzhou
# Number of items_boutique: 1
# Number of items_retailer: 4
# Number of items_distribu: 7
# cn/jiangsu/huaian
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu/jiangyin
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu/kunshan
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu/lianyungang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/nanjing
# Number of items_boutique: 3
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/jiangsu/nantong
# Number of items_boutique: 2
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/jiangsu/suqian
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/suzhou
# Number of items_boutique: 3
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/jiangsu/taicang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/taizhou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu/wuxi
# Number of items_boutique: 2
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/jiangsu/xuzhou
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/yancheng
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/jiangsu/yangzhou
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/yixing
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangsu/zhangjiagang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangsu/zhenjiang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangxi
# cn/jiangxi/ganzhou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/jiangxi/jingdezhen
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangxi/jiujiang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jiangxi/nanchang
# Number of items_boutique: 1
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/jiangxi/yichun
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/jilin
# cn/jilin/changchun
# Number of items_boutique: 1
# Number of items_retailer: 7
# Number of items_distribu: 7
# cn/jilin/jilin
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/liaoning
# cn/liaoning/anshan
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/benxi
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/liaoning/chaoyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/dalian
# Number of items_boutique: 1
# Number of items_retailer: 6
# Number of items_distribu: 7
# cn/liaoning/dandong
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/liaoning/fushun
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/fuxin
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/haicheng
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/huludao
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/jingzhou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/liaoning/liaoyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/panjin
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/liaoning/shenyang
# Number of items_boutique: 6
# Number of items_retailer: 10
# Number of items_distribu: 7
# cn/liaoning/yingkou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/ningxia
# cn/ningxia/yinchuan
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/qinghai
# cn/qinghai/xining
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shaanxi
# cn/shaanxi/baoji
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shaanxi/xian
# Number of items_boutique: 4
# Number of items_retailer: 7
# Number of items_distribu: 7
# cn/shandong
# cn/shandong/dezhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/dongying
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/shandong/jinan
# Number of items_boutique: 2
# Number of items_retailer: 4
# Number of items_distribu: 7
# cn/shandong/jining
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/shandong/liaocheng
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/linyi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/qingdao
# Number of items_boutique: 2
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/shandong/taian
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/weifang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/weihai
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/yantai
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shandong/zibo
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shanghai
# cn/shanghai/shanghai
# Number of items_boutique: 10
# Number of items_retailer: 24
# Number of items_distribu: 7
# cn/shanxi
# cn/shanxi/datong
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/shanxi/jincheng
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/shanxi/taiyuan
# Number of items_boutique: 2
# Number of items_retailer: 4
# Number of items_distribu: 7
# cn/shanxi/yangquan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/sichuan
# cn/sichuan/chengdu
# Number of items_boutique: 4
# Number of items_retailer: 12
# Number of items_distribu: 7
# cn/sichuan/deyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/sichuan/leshan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/sichuan/luzhou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/sichuan/mianyang
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/sichuan/nanchong
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/sichuan/suining
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/tianjin
# cn/tianjin/tianjin
# Number of items_boutique: 4
# Number of items_retailer: 4
# Number of items_distribu: 7
# cn/xinjiang
# cn/xinjiang/karamay
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/xinjiang/kuerle
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/xinjiang/wulumuqi
# Number of items_boutique: 0
# Number of items_retailer: 4
# Number of items_distribu: 7
# cn/xinjiang/yili
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/xizangtibet
# cn/xizangtibet/lasa
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/yunnan
# cn/yunnan/kunming
# Number of items_boutique: 1
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/yunnan/ruili
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang
# cn/zhejiang/cixi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/dongyang
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/fenghua
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/haining
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/hangzhou
# Number of items_boutique: 6
# Number of items_retailer: 11
# Number of items_distribu: 7
# cn/zhejiang/huzhou
# Number of items_boutique: 1
# Number of items_retailer: 0
# Number of items_distribu: 7
# cn/zhejiang/jiaxin
# Number of items_boutique: 1
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/zhejiang/jinghua
# Number of items_boutique: 1
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/zhejiang/lishui
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/ningbo
# Number of items_boutique: 2
# Number of items_retailer: 5
# Number of items_distribu: 7
# cn/zhejiang/quzhou
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/shangyu
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/shaoxing
# Number of items_boutique: 1
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/taizhou
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 7
# cn/zhejiang/wenzhou
# Number of items_boutique: 2
# Number of items_retailer: 0
# Number of items_distribu: 7
# cn/zhejiang/yiwu
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 7
# cn/zhejiang/yuyao
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/zhoushan
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# cn/zhejiang/zhuji
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 7
# co
# co/amazonas
# co/amazonas/leticia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# co/antioquia
# co/antioquia/medellin
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# co/atlantico
# co/atlantico/barranquilla
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 1
# co/bogota
# co/bogota/bogota
# Number of items_boutique: 0
# Number of items_retailer: 12
# Number of items_distribu: 1
# co/cordoba
# co/cordoba/monteria
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# co/huila
# co/huila/neiva
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# co/meta
# co/meta/villavicencio
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# co/northsantander
# co/northsantander/cucuta
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# co/risaralda
# co/risaralda/pereira
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# co/santander
# co/santander/bucaramanga
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# co/tolima
# co/tolima/ibague
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# co/valledelcauca
# co/valledelcauca/cali
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# cg
# cg/kouilou
# cg/kouilou/pointenoire
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# cr
# cr/sanjose
# cr/sanjose/escazu
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# hr
# hr/cityofzagreb
# hr/cityofzagreb/zagreb
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 0
# hr/istriacounty
# hr/istriacounty/porec
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# hr/osijekbaranjacounty
# hr/osijekbaranjacounty/osijek
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# hr/splitdalmatiacounty
# hr/splitdalmatiacounty/split
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# hr/zadarcounty
# hr/zadarcounty/zadar
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# cu
# cu/havana
# cu/havana/lahabana
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 0
# cu/matanzas
# cu/matanzas/varadero
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# cw
# cw/otrobanda
# cw/otrobanda/willemstad
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# cy
# cy/larnaca
# cy/larnaca/larnaca
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# cy/limassol
# cy/limassol/limassol
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# cy/nicosia
# cy/nicosia/nicosia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 0
# cy/paphos
# cy/paphos/paphos
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 0
# cz
# cz/hlavnimstopraha
# cz/hlavnimstopraha/praha
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 1
# cz/hradeckraloveregion
# cz/hradeckraloveregion/hradeckralove
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cz/karlovyvaryregion
# cz/karlovyvaryregion/karlovyvary
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# cz/moraviansilesianregion
# cz/moraviansilesianregion/ostrava
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# cz/olomoucregion
# cz/olomoucregion/olomouc
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ...
# us/florida/naples
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/florida/orlando
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# us/florida/tallahassee
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/florida/tampa
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/florida/winterpark
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/georgia
# us/georgia/alpharetta
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/georgia/atlanta
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/georgia/buford
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# us/georgia/kennesaw
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/georgia/savannah
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/hamilton
# us/hamilton/hamilton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/hawaii
# us/hawaii/honolulu
# Number of items_boutique: 1
# Number of items_retailer: 5
# Number of items_distribu: 1
# us/illinois
# us/illinois/chicago
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# us/illinois/glenview
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/illinois/northriverside
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/illinois/oakbrook
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/illinois/oakbrookterrace
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/illinois/schaumburg
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/illinois/skokie
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/indiana
# us/indiana/indianapolis
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/indiana/mishawaka
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/kansas
# us/kansas/overlandpark
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/kentucky
# us/kentucky/louisville
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/louisiana
# us/louisiana/metairie
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/maryland
# us/maryland/bethesda
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/maryland/chevychase
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/maryland/columbia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/maryland/gambrills
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/massachusetts
# us/massachusetts/boston
# Number of items_boutique: 0
# Number of items_retailer: 6
# Number of items_distribu: 1
# us/massachusetts/burlington
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/massachusetts/chestnuthill
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/massachusetts/everett
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/massachusetts/framingham
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/massachusetts/newtonhighlands
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/massachusetts/peabody
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan
# us/michigan/annarbor
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/auburnhills
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/birminghammi
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/bloomfieldhills
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/romulus
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/troy
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/michigan/utica
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/minnesota
# us/minnesota/bloomington
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/minnesota/minneapolis
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/missouri
# us/missouri/kansascity
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/nebraska
# us/nebraska/omaha
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/nevada
# us/nevada/lasvegas
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# us/nevada/reno
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newhampshire
# us/newhampshire/nashua
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newhampshire/salem
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey
# us/newjersey/bridgewatertownship
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newjersey/cherryhill
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/clifton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/edison
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newjersey/englewoodnj
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/fords
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/hackensack
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/hoboken
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/jerseycity
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/marlton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/morrisplains
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/newark
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newjersey/newjersey
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/paramus
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/pinebrook
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newjersey/secaucus
# Number of items_boutique: 0
# Number of items_retailer: 0
# Number of items_distribu: 1
# us/newjersey/shorthills
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newjersey/wayne
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork
# us/newyork/brooklyn
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# us/newyork/cedarhurst
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/centralvalley
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/easthampton
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/elmhurst
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/flushing
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newyork/foresthills
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/gardencity
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/newyork/greatneck
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/hicksville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/huntingtonstation
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/manhasset
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/monsey
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/newyork
# Number of items_boutique: 1
# Number of items_retailer: 12
# Number of items_distribu: 1
# us/newyork/rochester
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/schenectady
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/valleystream
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/newyork/whiteplains
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/northcarolina
# us/northcarolina/charlotte
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/northcarolina/durham
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/northcarolina/raleigh
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/northcarolina/winstonsalem
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/northdakota
# us/northdakota/fargo
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/ohio
# us/ohio/cincinnati
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/ohio/columbus
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/ohio/fairlawn
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/oklahoma
# us/oklahoma/oklahomacity
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/oklahoma/thackerville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/oregon
# us/oregon/portland
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/palmbeach
# us/palmbeach/palmbeach
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/pennsylvania
# us/pennsylvania/kingofprussia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/pennsylvania/lancaster
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/pennsylvania/pittsburgh
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/pennsylvania/willowgrove
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/southcarolina
# us/southcarolina/columbia
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/southcarolina/mtpleasant
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/tennessee
# us/tennessee/brentwood
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/tennessee/franklin
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/tennessee/knoxville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/tennessee/murfreesboro
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/tennessee/nashville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas
# us/texas/arlington
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/baytown
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/cedarpark
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/dallas
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# us/texas/dfwairport
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/fortworth
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/frisco
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/houston
# Number of items_boutique: 0
# Number of items_retailer: 7
# Number of items_distribu: 1
# us/texas/lewisville
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/sanantonio
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/sugarland
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/thewoodlands
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/texas/webster
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/utah
# us/utah/saltlakecity
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/virginia
# us/virginia/arlington
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/virginia/fallschurch
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/virginia/leesburg
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/virginia/mclean
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# us/virginia/virginiabeach
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/washington
# us/washington/bellevue
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 1
# us/washington/kennewick
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/washington/seattle
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/washington/spokane
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/washington/tukwila
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# us/wisconsin
# us/wisconsin/brookfield
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# uy
# uy/maldonado
# uy/maldonado/puntadeleste
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# uy/montevideodepartment
# uy/montevideodepartment/montevideo
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 1
# uz
# uz/tashkent
# uz/tashkent/tashkent
# Number of items_boutique: 0
# Number of items_retailer: 5
# Number of items_distribu: 0
# vn
# vn/camranh
# vn/camranh/camranh
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 2
# vn/haiphong
# vn/haiphong/haiphong
# Number of items_boutique: 0
# Number of items_retailer: 2
# Number of items_distribu: 2
# vn/hanoi
# vn/hanoi/hanoi
# Number of items_boutique: 1
# Number of items_retailer: 9
# Number of items_distribu: 2
# vn/hochiminh
# vn/hochiminh/hochiminh
# Number of items_boutique: 1
# Number of items_retailer: 8
# Number of items_distribu: 2
# vn/langsonprovince
# vn/langsonprovince/langson
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 2
# vn/qungninh
# vn/qungninh/vungtau
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 2
# ye
# ye/aden
# ye/aden/aden
# Number of items_boutique: 0
# Number of items_retailer: 1
# Number of items_distribu: 1
# ye/amanatalasimah
# ye/amanatalasimah/sanaa
# Number of items_boutique: 0
# Number of items_retailer: 3
# Number of items_distribu: 1
# total stores: 4196

# %%
len(df)
# Out:
# 4196

# %%
brand = 'LONGINES'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/LONGINES_092021.xlsx

# %% [markdown]
# # RICHARD MILLE

# %%
config = config_all['RICHARD MILLE']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = driver.find_elements_by_xpath(config["country_code"])

print("Number of countries=",len(country_codes))

for idx in range(len(country_codes)):

    country = driver.find_element_by_xpath(config["country_code"]+ '['+ str(idx+1) +']')
    country.click()
    time.sleep(3)
      
    items = get_items(driver, config["items"])
    print("Number of items:",len(items))

    for item in items:
        rows_list.append({
                'store_name': get_value(item,config,'store_name'),
                'store_address1': get_value(item,config,'store_address1'),
                'store_address2': get_value(item,config,'store_address2'),
                'store_address3': get_value(item,config,'store_address3'),
                'country': get_value(item,config,'country'),
                'brand': "Richard Mille",
                'is_partner': '1'
            })

df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
# Out:
# Number of countries= 24
# Number of items: 0
# Number of items: 1
# Number of items: 1
# Number of items: 5
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 6
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 2
# Number of items: 1
# Number of items: 1
# Number of items: 1
# Number of items: 2
# Number of items: 1
# Number of items: 8
# Number of items: 1
# total stores: 41

# %%
len(df)
# Out:
# 41

# %%
brand = 'RICHARD_MILLE'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/RICHARD_MILLE_092021.xlsx

# %% [markdown]
# # CHOPARD

# %%
config = config_all['CHOPARD']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
country_codes = get_items(driver, config["country_code"])
print("Number of countries=",len(country_codes))

for country_code in country_codes:
    print(country_code)
    url_country = "https://www.chopard.com/intl/storelocator" + "?country=" + country_code
    
    driver.get(url_country)
    time.sleep(3)
         
    items = get_items(driver, config["items"])
    print("Items=",len(items))
    for item in items:
        rows_list.append({
                'store_name': get_value(item,config,'store_name'),
                'store_address1': get_value(item,config,'store_address1'),
                'store_address2': get_value(item,config,'store_address2'),
                'brand': "Chopard"
            })
            
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))
df['is_partner'] = df['store_name'].apply(lambda x : extract_partner(x, 'Chopard'))
# Out:
# Number of countries= 126
# AL
# Items= 1
# DZ
# Items= 2
# AD
# Items= 2
# AR
# Items= 4
# AM
# Items= 1
# AW
# Items= 3
# AU
# Items= 12
# AT
# Items= 16
# AZ
# Items= 2
# BS
# Items= 0
# BH
# Items= 5
# BB
# Items= 1
# BE
# Items= 11
# BA
# Items= 2
# BR
# Items= 0
# VG
# Items= 1
# BG
# Items= 1
# KH
# Items= 1
# CA
# Items= 12
# KY
# Items= 1
# TW
# Items= 20
# CO
# Items= 7
# CG
# Items= 0
# CR
# Items= 1
# HR
# Items= 1
# CW
# Items= 3
# CY
# Items= 2
# CZ
# Items= 3
# CI
# Items= 1
# DK
# Items= 3
# DO
# Items= 0
# EC
# Items= 3
# EG
# Items= 3
# EE
# Items= 1
# FI
# Items= 4
# FR
# Items= 79
# GF
# Items= 1
# GE
# Items= 1
# DE
# Items= 89
# GI
# Items= 1
# GR
# Items= 8
# GU
# Items= 0
# GT
# Items= 3
# HT
# Items= 1
# HN
# Items= 0
# HK
# Items= 28
# HU
# Items= 1
# IN
# Items= 11
# ID
# Items= 4
# IQ
# Items= 1
# IE
# Items= 1
# IL
# Items= 2
# IT
# Items= 72
# JM
# Items= 2
# JP
# Items= 47
# JO
# Items= 2
# KZ
# Items= 2
# KW
# Items= 9
# KG
# Items= 0
# LV
# Items= 1
# LB
# Items= 4
# LI
# Items= 2
# LT
# Items= 1
# LU
# Items= 2
# CN
# Items= 50
# MO
# Items= 6
# MY
# Items= 2
# MV
# Items= 1
# MT
# Items= 2
# MU
# Items= 0
# MX
# Items= 16
# MD
# Items= 1
# MC
# Items= 1
# MN
# Items= 0
# ME
# Items= 1
# MA
# Items= 5
# NP
# Items= 1
# NL
# Items= 18
# NC
# Items= 0
# NZ
# Items= 3
# NG
# Items= 3
# MP
# Items= 1
# NO
# Items= 3
# OM
# Items= 1
# PK
# Items= 1
# PA
# Items= 0
# PY
# Items= 3
# PE
# Items= 2
# PH
# Items= 4
# PL
# Items= 5
# PT
# Items= 11
# PR
# Items= 1
# QA
# Items= 7
# RO
# Items= 2
# RU
# Items= 26
# SA
# Items= 9
# RS
# Items= 1
# SG
# Items= 12
# SX
# Items= 2
# SK
# Items= 2
# SI
# Items= 1
# ZA
# Items= 2
# KR
# Items= 18
# ES
# Items= 32
# LK
# Items= 1
# BL
# Items= 1
# KN
# Items= 1
# LC
# Items= 0
# SR
# Items= 1
# SE
# Items= 5
# CH
# Items= 57
# TH
# Items= 7
# TN
# Items= 5
# TR
# Items= 8
# TM
# Items= 1
# TC
# Items= 1
# VI
# Items= 0
# UA
# Items= 1
# AE
# Items= 23
# GB
# Items= 43
# US
# Items= 70
# UY
# Items= 1
# UZ
# Items= 1
# VE
# Items= 1
# VN
# Items= 2
# ZW
# Items= 0
# total stores: 986

# %%
len(df)
# Out:
# 986

# %%
brand = 'CHOPARD'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/CHOPARD_092021.xlsx

# %% [markdown]
# # BVLGARI

# %%
config = config_all['BVLGARI']

# %%
driver.get(config['start_url'][0])

# %%
rows_list = []

# %%
countries_url = get_items(driver, config["country"])
print("Number of countries=",len(countries_url))

for country_url in countries_url:
    print(country_url)
    driver.get(country_url)
    time.sleep(3)
    
    items = get_items(driver, config["items"])
    
    for item in items:
        store_name = get_value(item,config,'store_name')
        store_boutique = get_value(item,config,'store_boutique') 
        store_address = get_value(item,config,'store_address')
        rows_list.append({
                'store_name': store_name,
                'store_boutique': store_boutique,
                'store_address': store_address,
                'brand': "Bvlgari"
            })           
    
df = pd.DataFrame(rows_list)
df.drop_duplicates(inplace=True)
print('total stores:', len(df))    
df['is_partner'] = df['store_boutique'].apply(lambda x : extract_partner(x, 'Bvlgari'))
# Out:
# Number of countries= 98
# https://www.bulgari.com/en-int/storelocator/angola
# https://www.bulgari.com/en-int/storelocator/egypt
# https://www.bulgari.com/en-int/storelocator/morocco
# https://www.bulgari.com/en-int/storelocator/r%C3%A9union
# https://www.bulgari.com/en-int/storelocator/south+africa
# https://www.bulgari.com/en-int/storelocator/tunisia
# https://www.bulgari.com/en-int/storelocator/azerbaijan
# https://www.bulgari.com/en-int/storelocator/bahrain
# https://www.bulgari.com/en-int/storelocator/cambodia
# https://www.bulgari.com/en-int/storelocator/georgia
# https://www.bulgari.com/en-int/storelocator/hong+kong+s.a.r.
# https://www.bulgari.com/en-int/storelocator/india
# https://www.bulgari.com/en-int/storelocator/indonesia
# https://www.bulgari.com/en-int/storelocator/iraq
# https://www.bulgari.com/en-int/storelocator/israel
# https://www.bulgari.com/en-int/storelocator/japan
# https://www.bulgari.com/en-int/storelocator/jordan
# https://www.bulgari.com/en-int/storelocator/kazakhstan
# https://www.bulgari.com/en-int/storelocator/kuwait
# https://www.bulgari.com/en-int/storelocator/lebanon
# https://www.bulgari.com/en-int/storelocator/macau+s.a.r.
# https://www.bulgari.com/en-int/storelocator/mainland+china
# https://www.bulgari.com/en-int/storelocator/malaysia
# https://www.bulgari.com/en-int/storelocator/nepal
# https://www.bulgari.com/en-int/storelocator/oman
# https://www.bulgari.com/en-int/storelocator/philippines
# https://www.bulgari.com/en-int/storelocator/qatar
# https://www.bulgari.com/en-int/storelocator/saudi+arabia
# https://www.bulgari.com/en-int/storelocator/singapore
# https://www.bulgari.com/en-int/storelocator/south+korea
# https://www.bulgari.com/en-int/storelocator/sri+lanka
# https://www.bulgari.com/en-int/storelocator/taiwan+region
# https://www.bulgari.com/en-int/storelocator/thailand
# https://www.bulgari.com/en-int/storelocator/turkmenistan
# https://www.bulgari.com/en-int/storelocator/united+arab+emirates
# https://www.bulgari.com/en-int/storelocator/vietnam
# https://www.bulgari.com/en-int/storelocator/andorra
# https://www.bulgari.com/en-int/storelocator/austria
# https://www.bulgari.com/en-int/storelocator/belgium
# https://www.bulgari.com/en-int/storelocator/czech+republic
# https://www.bulgari.com/en-int/storelocator/denmark
# https://www.bulgari.com/en-int/storelocator/estonia
# https://www.bulgari.com/en-int/storelocator/finland
# https://www.bulgari.com/en-int/storelocator/france
# https://www.bulgari.com/en-int/storelocator/germany
# https://www.bulgari.com/en-int/storelocator/gibraltar
# https://www.bulgari.com/en-int/storelocator/greece
# https://www.bulgari.com/en-int/storelocator/hungary
# https://www.bulgari.com/en-int/storelocator/italy
# https://www.bulgari.com/en-int/storelocator/latvia
# https://www.bulgari.com/en-int/storelocator/luxembourg
# https://www.bulgari.com/en-int/storelocator/malta
# https://www.bulgari.com/en-int/storelocator/monaco
# https://www.bulgari.com/en-int/storelocator/norway
# https://www.bulgari.com/en-int/storelocator/poland
# https://www.bulgari.com/en-int/storelocator/portugal
# https://www.bulgari.com/en-int/storelocator/romania
# https://www.bulgari.com/en-int/storelocator/russia
# https://www.bulgari.com/en-int/storelocator/saint+barth%C3%A9lemy
# https://www.bulgari.com/en-int/storelocator/san+marino
# https://www.bulgari.com/en-int/storelocator/slovakia
# https://www.bulgari.com/en-int/storelocator/spain
# https://www.bulgari.com/en-int/storelocator/sweden
# https://www.bulgari.com/en-int/storelocator/switzerland
# https://www.bulgari.com/en-int/storelocator/the+netherlands
# https://www.bulgari.com/en-int/storelocator/turkey
# https://www.bulgari.com/en-int/storelocator/ukraine
# https://www.bulgari.com/en-int/storelocator/united+kingdom
# https://www.bulgari.com/en-int/storelocator/aruba
# https://www.bulgari.com/en-int/storelocator/bahamas
# https://www.bulgari.com/en-int/storelocator/barbados
# https://www.bulgari.com/en-int/storelocator/belize
# https://www.bulgari.com/en-int/storelocator/canada
# https://www.bulgari.com/en-int/storelocator/cayman+islands
# https://www.bulgari.com/en-int/storelocator/costa+rica
# https://www.bulgari.com/en-int/storelocator/dominican+republic
# https://www.bulgari.com/en-int/storelocator/guatemala
# https://www.bulgari.com/en-int/storelocator/haiti
# https://www.bulgari.com/en-int/storelocator/jamaica
# https://www.bulgari.com/en-int/storelocator/mexico
# https://www.bulgari.com/en-int/storelocator/netherlands+antilles
# https://www.bulgari.com/en-int/storelocator/puerto+rico
# https://www.bulgari.com/en-int/storelocator/saint+kitts+and+nevis
# https://www.bulgari.com/en-int/storelocator/saint+lucia
# https://www.bulgari.com/en-int/storelocator/turks+and+caicos+islands
# https://www.bulgari.com/en-int/storelocator/u.s.+virgin+islands
# https://www.bulgari.com/en-int/storelocator/united+states
# https://www.bulgari.com/en-int/storelocator/australia
# https://www.bulgari.com/en-int/storelocator/new+zealand
# https://www.bulgari.com/en-int/storelocator/argentina
# https://www.bulgari.com/en-int/storelocator/bolivia
# https://www.bulgari.com/en-int/storelocator/brazil
# https://www.bulgari.com/en-int/storelocator/chile
# https://www.bulgari.com/en-int/storelocator/colombia
# https://www.bulgari.com/en-int/storelocator/ecuador
# https://www.bulgari.com/en-int/storelocator/peru
# https://www.bulgari.com/en-int/storelocator/uruguay
# https://www.bulgari.com/en-int/storelocator/venezuela
# total stores: 1006

# %%
len(df)
# Out:
# 1006

# %%
brand = 'BVLGARI'
mmyyyy = '092021'
fpath = '../raw/' + mmyyyy + '/'+ brand + '_'+ mmyyyy + '.xlsx'
print('saving file in folder:', fpath)
writer = pd.ExcelWriter(fpath, engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
# Out:
# saving file in folder: ../raw/092021/BVLGARI_092021.xlsx

# %% [markdown]
# # CLEAN AND SAVE

# %%
import pandas as pd
import numpy as np
import os
import re

# %%
path_raw_data = '../raw/092021'

df = pd.DataFrame()

for f in os.listdir(path_raw_data):
    print(f)
    #EXCLUDE ALREADY COMPUTED DF
    if 'INSERT' not in f:
        if '.xlsx' in f:
            fname = re.sub('_[0-9]{5,}\.xlsx', '', f)
            dfc = pd.read_excel(os.path.join(path_raw_data, f), encoding='utf8')
        elif '.csv' in f:
            fname = re.sub('_[0-9]{5,}\.csv', '', f)
            dfc = pd.read_csv(os.path.join(path_raw_data, f), sep=',', encoding='utf8')    
        fname = re.sub('_', ' ', fname)
        
        if fname == 'LOUIS VUITTON':
            #add extract retailers algorithm
            dfc['is_partner'] = 0
            dfc['brand'] = 'Louis Vuitton'
        if fname == 'PATEK PHILIPPE':
            dfc['store_address'] = dfc['country'] + ', ' + dfc['city'] + ', ' + dfc['address']
        if fname == 'AUDEMARS PIGUET':
            dfc['store_address'] = dfc['address_city']
        if fname == 'BREGUET':
            dfc['store_address'] = dfc['city'] + ', ' + dfc['address']
        if fname == 'CARTIER':
            dfc.replace(np.nan, '', inplace=True)
            dfc['store_address'] = dfc['country'] + ', ' + dfc['city'] + ', ' + dfc['address']
        if fname == 'CHANEL':
            dfc['store_address'] = dfc['city'] + ', ' + dfc['address']
        if fname == 'DIOR':
            dfc['store_address'] = dfc['city'] + ', ' + dfc['address']
        if fname == 'FERRARI':
            dfc['store_address'] = dfc['country'] + ', ' + dfc['city']
        if fname == 'HERMES':
            dfc['store_address'] = dfc['country'] + ', ' + dfc['address_city']
        if fname == 'LAMBORGHINI':
            dfc['store_address'] = dfc['address']
        if fname == 'ROLEX':
            dfc.replace(np.nan, '', inplace=True)
            #suppress invisible characters
            dfc['store_name'] = dfc['store_name'].apply(lambda x : re.sub('\u202c', '', x)) 
            dfc['store_name'] = dfc['store_name'].apply(lambda x : re.sub('\u202d', '', x))
            
            dfc['store_address'] = dfc['info5'] + ', ' + dfc['info4'] + ', ' + dfc['info3'] + ', ' + dfc['info2'] + ', ' + dfc['info1']
        if fname == 'VACHERON CONSTANTIN':
            dfc['store_address'] = dfc['country'] + ', ' + dfc['city'] + ', ' + dfc['address']

        #if fname == 'HUBLOT':
            #dfc['store_address'] = dfc['store_address'].apply(lambda x: re.sub(r'[\n\r\t]', '', x))
        if fname == 'OMEGA':
            #dfc.replace(np.nan, '', inplace=True)
            #dfc['store_address'] = dfc['store_address1'] + ', ' + dfc['store_address2'] + ', ' + dfc['store_address3'] + ', ' + dfc['store_address4'] + ', ' + dfc['store_address5'] + dfc['store_address6'] + ', ' + dfc['store_address7']
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3','store_address4','store_address5','store_address6','store_address7']].apply(lambda x: ', '.join(x.dropna()), axis=1)
        if fname == 'TAGHEUER':
            #dfc.replace(np.nan, '', inplace=True)
            #dfc['store_address'] = dfc['store_address1'] + ', ' + dfc['store_address2'] + ', ' + dfc['store_address3'] + ', ' + dfc['store_address4'] + ', ' + dfc['store_address5']
            dfc.replace(',', np.nan, inplace=True)
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3']].apply(lambda x: ', '.join(x.dropna()), axis=1)
        if fname == 'ZENITH':
            #dfc.replace(np.nan, '', inplace=True)
            #dfc['store_address'] = dfc['store_address1'] + ', ' + dfc['store_address2'] + ', ' + dfc['store_address3'] 
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3']].apply(lambda x: ', '.join(x.dropna()), axis=1)

        if fname == 'CHOPARD':
            dfc['store_address'] = dfc[['store_address1','store_address2']].apply(lambda x: ', '.join(x.dropna()), axis=1)
        if fname == 'GIRARD PERREGAUX':
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3']].apply(lambda x: ', '.join(x.dropna()), axis=1)            
        if fname == 'LONGINES':
            dfc['store_name'] = dfc[['store_name1','store_name2']].apply(lambda x: ', '.join(x.dropna()), axis=1)
            dfc['store_address'] = dfc[['store_address1','store_address2']].apply(lambda x: ', '.join(x.dropna()), axis=1)            
        if fname == 'RICHARD MILLE':
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3']].apply(lambda x: ', '.join(x.dropna()), axis=1)            
        if fname == 'TUDOR':
            dfc['store_name'] = dfc[['store_name1','store_name2']].apply(lambda x: ', '.join(x.dropna()), axis=1)            
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3','store_address4','store_address5','store_address6']].apply(lambda x: ', '.join(x.dropna()), axis=1)            
        if fname == 'ULYSSE NARDIN':
            dfc['store_address'] = dfc[['store_address1','store_address2','store_address3','country']].apply(lambda x: ', '.join(x.dropna()), axis=1)            

        dfc = dfc[['brand', 'store_name', 'store_address', 'is_partner']]
        df = pd.concat([df, dfc], ignore_index=True)
    
print('total length:', len(df))
# Out:
# AUDEMARS_PIGUET_092021.xlsx
# BREGUET_092021.xlsx
# BVLGARI_092021.xlsx
# CARTIER_092021.xlsx
# CHANEL_092021.xlsx
# CHOPARD_092021.xlsx
# DIOR_092021.xlsx
# FERRARI_092021.xlsx
# GIRARD_PERREGAUX_092021.xlsx
# HERMES_092021.xlsx
# HUBLOT_092021.xlsx
# LAMBORGHINI_092021.xlsx
# LONGINES_092021.xlsx
# LOUIS_VUITTON_092021.csv
# OMEGA_092021.xlsx
# PATEK_PHILIPPE_092021.xlsx
# RICHARD_MILLE_092021.xlsx
# ROLEX_092021.xlsx
# TAGHEUER_092021.xlsx
# TUDOR_092021.xlsx
# ULYSSE_NARDIN_092021.xlsx
# VACHERON_CONSTANTIN_092021.xlsx
# ZENITH_092021.xlsx
# total length: 19877

# %%
df.head()
# Out:
#              brand                                        store_name  \
# 0  Audemars Piguet                                AP House Barcelona
# 1  Audemars Piguet                                   AP House Madrid
# 2  Audemars Piguet                   Audemars Piguet Boutique Monaco
# 3  Audemars Piguet          Audemars Piguet Boutique Geneva Fusterie
# 4  Audemars Piguet  Audemars Piguet Boutique Geneva Montres Prestige
#
#                                        store_address  is_partner
# 0              Passeig de Gracia 37, 08006 Barcelona           0
# 1                 Calle de Serrano, 66, 28001 Madrid           0
# 2               2 avenue des Spélugues, 98000 Monaco           0
# 3               Place de la Fusterie 12, 1204 Geneva           0
# 4  Quai du mont-blanc 19, Fairmont Grand Hôtel, 1...           0

# %%
df[df['brand']=='Lamborghini']
# Out:
#             brand                                   store_name  \
# 5627  Lamborghini                Exclusive Cars Vertriebs Gmbh
# 5628  Lamborghini  Jemercar Tecnicos Del Automovil Services SL
# 5629  Lamborghini                                      Siva SA
# 5630  Lamborghini   Saudi Arabian Marketing & Agencies Co. Ltd
# 5631  Lamborghini             Fouad Alghanim & Sons Automotive
# ...           ...                                          ...
# 5776  Lamborghini                                  RPM Co. Ltd
# 5777  Lamborghini                  Tajima Motor Corporation Co
# 5778  Lamborghini                      Zagame Automotive Group
# 5779  Lamborghini                         Sqda Motors Co., Ltd
# 5780  Lamborghini              Zagame Automotive Group Pty Ltd
#
#                                           store_address  is_partner
# 5627  ul. Polczynska 120 B 00-347 Warszawa PL 00-347...           0
# 5628  Via de Las Dos Castillas 9 28224 Pozuelo De Al...           0
# 5629  Rua São Francisco 582, Alcabideche 2645-019 Al...           0
# 5630  Pr. Mohammed Bin Abdul Aziz Street P.O. Box :3...           0
# 5631  Al-Tilal Complex, Pepsi Road 80, Shuwaikh Indu...           0
# ...                                                 ...         ...
# 5776  4-34-4 HARADA HIGASHI-KU FUKUOKA-SHI 812 0063 ...           0
# 5777  44-1, Shinden, Nanakita, Izumi-ku, Sendai-shi,...           0
# 5778  382 Swan St. Richmond 'Vic 3141 Richmond VIC A...           0
# 5779  622(Samsung-dong) Yeongdong-daero, Gangnam-gu ...           0
# 5780  269-275 Glen Osmond Road Frewville SA null Ade...           0
#
# [154 rows x 4 columns]

# %%
NAME_SL = 'SL_ALL_092021_INSERT'
writer = pd.ExcelWriter(os.path.join(path_raw_data, NAME_SL + '.xlsx'), engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()

# %% [markdown]
# # INSERTION AND PARSING

# %% [markdown]
# - insert stores : insert_stores.py
# - python3 -m store_locator.insert_stores data_to_push/SL_ALL_102020_INSERT.xlsx 2020-10-26 -p

# %% [markdown]
# - parse stores : parse_stores.py
# - python3 -m store_locator.parse_stores "Q4 October 2020" --brand "Audemars Piguet" -p

# %% [markdown]
# # CHECK UPDATED STORES STATUS

# %% [markdown]
# When collecting data and checking changes between 2 months you have:
# - New stores (Real new stores that pop on the website)
# - Closed stores (Real closed stores that doesn't appear on the website)
# - Closed stores detected because you have forgotten to search for a specific place
# - New stores detected because someone changed the address but should be compensated with a closed store

# %% [markdown]
# - Sort by store_name and check store_name and store_address similarity

# %% [markdown]
# To find the link new-closed due to a change in the text of either the store name or store address
# - Check new status : change status "new" to "-" and discard the corresponding closed store (by putting discarded to 1)

# %% [markdown]
# - Check closed status : check that you have not forgotten any place when scraping
